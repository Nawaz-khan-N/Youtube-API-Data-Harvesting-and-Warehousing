# %% [markdown]
# # Youtube API Data Harvesting & Warehousing

# %% [markdown]
# ###### From Youtube API, we fetch the given Channels, its Videos & each Videos Comments are fetched & then added to MongoDB.
# ###### Then we need to fetch from MongoDB and do some transformation and store it in MYSQL.

# %%
import pandas
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyBOmQQcbMkMCi0wqKjtt_LZBcQgrSgIMGA'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def getComments(vId):
    request = youtube.commentThreads().list(
    part="snippet",
    videoId=vId
    )
    response = request.execute()

    #Getting count of total comments on video
    count = response['pageInfo']['totalResults']

    #Empty list to have all comments
    totalcomments = {}

    if count == 0:
        return totalcomments
    else:
        #Getting comments adding to dict
        for i in range(count):
            comment_info = {
            'Comment_Id' : response['items'][i]['id'],
            'Comment_Text' : response['items'][i]['snippet']['topLevelComment']['snippet']['textOriginal'],
            'Comment_Author' : response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
            'Comment_PublishedAt' : response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt']
            }
            #Variable to give each comment key name
            name = 'Comment_Id_'+str(i)
            totalcomments[name] = comment_info

    return totalcomments

# %%
def getVideos(vID):
    #Video Details based on Video ID
    request_video = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=vID
    )
    
    response_video = request_video.execute()
    
    response_Vd = response_video['items'][0]
        
    vid = response_Vd['id']
    vtitle = response_Vd['snippet']['title']
        
    if 'description' in response_Vd['snippet'].keys():
        vdesc = response_Vd['snippet']['description']
    else:
        vdesc = ''
    if 'tags' in response_Vd['snippet'].keys():
        vtag = response_Vd['snippet']['tags']
    else:
        vtag = ''
    vpub = response_Vd['snippet']['publishedAt']
    if 'viewCount' in response_Vd['statistics'].keys():
        vwc = response_Vd['statistics']['viewCount']
    else:
        vwc = 0
    if 'likeCount' in response_Vd['statistics'].keys():
        vlc = response_Vd['statistics']['likeCount']
    else:
        vlc = 0
    if 'dislikeCount' in response_Vd['statistics'].keys():
        vdc = response_Vd['statistics']['dislikeCount']
    else:
        vdc = 0
    if 'favoriteCount' in response_Vd['statistics'].keys():
        vfc = response_Vd['statistics']['favoriteCount']
    else:
        vfc = 0
    if 'commentCount' in response_Vd['statistics'].keys():
        vcc = response_Vd['statistics']['commentCount']
    else:
        vcc = 0
    vdur = response_Vd['contentDetails']['duration']
    if 'standard' in response_Vd['snippet']['thumbnails'].keys():
        vth = response_Vd['snippet']['thumbnails']['standard']['url']
    elif 'default' in response_Vd['snippet']['thumbnails'].keys():
        vth = response_Vd['snippet']['thumbnails']['default']['url']
    elif 'medium' in response_Vd['snippet']['thumbnails'].keys():
        vth = response_Vd['snippet']['thumbnails']['medium']['url']
    elif 'high' in response_Vd['snippet']['thumbnails'].keys():
        vth = response_Vd['snippet']['thumbnails']['high']['url']
    else:
        vth = ''
    if 'caption' in response_Vd['contentDetails'].keys():
        vcp = response_Vd['contentDetails']['caption']
    else:
        vcp = ''

    vid_stats = youtube.videos().list(
    part="statistics",
    id=vID
    ).execute()
    comment_count = vid_stats.get("items")[0].get("statistics").get("commentCount")

#    if int(comment_count) >= 0:
    video_info = {
            "Video_Id": vid,
            "Video_Name": vtitle,
            "Video_Description": vdesc,
            "Tags": vtag,
            "PublishedAt": vpub,
            "View_Count": vwc,
            "Like_Count": vlc,
            "Dislike_Count": vdc,
            "Favorite_Count": vfc,
            "Comment_Count": vcc,
            "Duration": vdur,
            "Thumbnail": vth,
            "Caption_Status": vcp,
            "Comments": getComments(vid)
            }
#    else:
 #       video_info = {
#            "Video_Id": vid,
#            "Video_Name": vtitle,
#            "Video_Description": vdesc,
#            "Tags": vtag,
#            "PublishedAt": vpub,
#            "View_Count": vwc,
#            "Like_Count": vlc,
#            "Dislike_Count": vdc,
#            "Favorite_Count": vfc,
#            "Comment_Count": vcc,
#            "Duration": vdur,
#            "Thumbnail": vth,
#            "Caption_Status": vcp,
#            "Comments": {}
#            }

    return video_info

# %%
def getChannel(chlId):
    
    response = youtube.channels().list(
    id=chlId,
    part='snippet,statistics,contentDetails'
    )
    channel_data = response.execute()

    chnl = {}
    
    #Getting Channel Info
    chl_info = {
        'channel_name' : channel_data['items'][0]['snippet']['title'],
        'channel_id' : channel_data['items'][0]['id'],
        'subscription_count' : channel_data['items'][0]['statistics']['subscriberCount'],
        'channel_views' : channel_data['items'][0]['statistics']['viewCount'],
        'channel_description' : channel_data['items'][0]['snippet']['description'],
        'playlists' : channel_data['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
    }

    chnl['Channel_Name'] = chl_info

    
    #First we get playlist Id & from that we will retrive the video details
    request_playlist = youtube.playlistItems().list(
        part="snippet,contentDetails",
        maxResults=25,
        playlistId=channel_data['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    )
    response_playlist = request_playlist.execute()

    nextPageToken = response_playlist.get('nextPageToken')
    
    while ('nextPageToken' in response_playlist):
        nextPage = youtube.playlistItems().list(
        part="snippet",
        playlistId=channel_data['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
        maxResults="50",
        pageToken=nextPageToken
        ).execute()
        response_playlist['items'] = response_playlist['items'] + nextPage['items']

        if 'nextPageToken' not in nextPage:
            response_playlist.pop('nextPageToken', None)
        else:
            nextPageToken = nextPage['nextPageToken']


    #Getting Count of the total videos in the playlist
    vc = response_playlist['pageInfo']['totalResults']

    vds = {}

    if vc == 0:
        chnl['Video_Id_1'] = vds
    else:
        for i in range(vc):
            vedio_ID = response_playlist['items'][i]['snippet']['resourceId']['videoId']
            x = 'Video_Id_' + str(i+1)
            chnl[x] = getVideos(vedio_ID)

    return chnl

# %%
ip = input("Enter Channel ID")
x = getChannel(ip)
x
# Out:
# Enter Channel ID UCu3BMqFAS8gKBXwNHdKM88w
# {'Channel_Name': {'channel_name': 'Cognitive Hub',
#   'channel_id': 'UCu3BMqFAS8gKBXwNHdKM88w',
#   'subscription_count': '5590',
#   'channel_views': '781339',
#   'channel_description': 'Work Hard until Light of your Study Table becomes Spot Light of Stage.\n\nLinkedIn URL:  https://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/ \n\nMail : ivsr517@gmail.com\n\nBlogSpot: https://cognitivehub2020.blogspot.com/\n',
#   'playlists': 'UUu3BMqFAS8gKBXwNHdKM88w'},
#  'Video_Id_1': {'Video_Id': 'Y_mWy11SxTo',
#   'Video_Name': '8. How to archive files in AWS S3 using Talend l USECASE l Talend',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #TalendUseCase\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'promoting jobs to Talend Cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3bucketcreate',
#    'ts3bucketdelete',
#    'ts3bucketexist'],
#   'PublishedAt': '2023-06-14T04:00:28Z',
#   'View_Count': '332',
#   'Like_Count': '3',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '6',
#   'Duration': 'PT11M26S',
#   'Thumbnail': 'https://i.ytimg.com/vi/Y_mWy11SxTo/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgyrgVLaVq7YZ8rugCh4AaABAg',
#     'Comment_Text': 'Hi bro nenu abinitio etl tool meda work chestuna present.i want to shift talend . how time it is required to learn and survive and is there any support is needed. please reply bro',
#     'Comment_Author': '@naveeng1752',
#     'Comment_PublishedAt': '2023-09-24T17:32:36Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugxo_ggvKb1OCqzU2_l4AaABAg',
#     'Comment_Text': 'Hi bro how can i convert string variables into interger data type. I am using intger.paraeint and it is showing an error.',
#     'Comment_Author': '@Ayush-jk2tu',
#     'Comment_PublishedAt': '2023-08-15T13:42:39Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgwrWvurbQ6FgZJDNA94AaABAg',
#     'Comment_Text': 'I want to connect you sir',
#     'Comment_Author': '@relaxingmusic5932',
#     'Comment_PublishedAt': '2023-07-17T06:26:27Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgytncheWXSzXABY1eZ4AaABAg',
#     'Comment_Text': 'Hi sir I need to learn talend pls help mee',
#     'Comment_Author': '@relaxingmusic5932',
#     'Comment_PublishedAt': '2023-07-17T06:25:52Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgySa5WMLUwamwIBdzp4AaABAg',
#     'Comment_Text': 'hii anna naku oka doubt vundee talend open studio loo',
#     'Comment_Author': '@relaxingmusic5932',
#     'Comment_PublishedAt': '2023-06-15T17:44:02Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgxMhXOLOh6lKU7YMod4AaABAg',
#     'Comment_Text': 'Please make videos for tac. Thank you',
#     'Comment_Author': '@vinodlondhe-cm8lz',
#     'Comment_PublishedAt': '2023-06-14T04:33:21Z'}}},
#  'Video_Id_2': {'Video_Id': 'G6vIcZ-A1QA',
#   'Video_Name': '7. How to copy files from one bucket to another bucket in AWS S3 using Talend components l ts3Copy',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #ts3Copy\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'promoting jobs to Talend Cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3bucketexist',
#    'ts3bucketcreate',
#    'ts3bucketdelete'],
#   'PublishedAt': '2023-06-07T04:00:07Z',
#   'View_Count': '289',
#   'Like_Count': '3',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT6M29S',
#   'Thumbnail': 'https://i.ytimg.com/vi/G6vIcZ-A1QA/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_3': {'Video_Id': 'iE0J837gSIc',
#   'Video_Name': '6. How to retrieve contents from a S3 Bucket using ts3List component in Talend l ts3List l Talend',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #ts3List\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'promoting jobs to Talend Cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3bucketexist',
#    'ts3bucketcreate',
#    'ts3bucketdelete'],
#   'PublishedAt': '2023-05-31T04:00:16Z',
#   'View_Count': '532',
#   'Like_Count': '7',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT7M16S',
#   'Thumbnail': 'https://i.ytimg.com/vi/iE0J837gSIc/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugzzh3s03KX90kOK2YV4AaABAg',
#     'Comment_Text': 'Hai subbarao good morning\nIf possible Can you make a video on realtime project in talend',
#     'Comment_Author': '@mohammadankoos5890',
#     'Comment_PublishedAt': '2023-05-31T04:24:35Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgyfkwwwcSKy7p86ogV4AaABAg',
#     'Comment_Text': 'Nice 🎉',
#     'Comment_Author': '@Alltec2233',
#     'Comment_PublishedAt': '2023-05-31T04:06:39Z'}}},
#  'Video_Id_4': {'Video_Id': 'HaLkoXi8kaA',
#   'Video_Name': '5. How to send files from talend studio to AWS S3 Bucket using tS3Put l ts3Put l Talend',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #ts3Put\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'creating multiple tasks in Talend cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3bucketexist',
#    'ts3bucketcreate',
#    'ts3bucketdelete'],
#   'PublishedAt': '2023-05-24T04:00:15Z',
#   'View_Count': '494',
#   'Like_Count': '8',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT4M58S',
#   'Thumbnail': 'https://i.ytimg.com/vi/HaLkoXi8kaA/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugw8CRpBkSV1ofseajF4AaABAg',
#     'Comment_Text': 'Nice\nBut we are excepting Tealtime related clips',
#     'Comment_Author': '@Alltec2233',
#     'Comment_PublishedAt': '2023-05-24T16:12:21Z'}}},
#  'Video_Id_5': {'Video_Id': 'Y3FJceP6MR4',
#   'Video_Name': '4. How to retrieve files from AWS S3 Buckets to Talend using tS3Get Component l tS3Get l Talend',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #ts3Get\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'creating multiple tasks in Talend cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3bucketexist',
#    'ts3bucketcreate',
#    'ts3bucketdelete'],
#   'PublishedAt': '2023-05-17T04:00:25Z',
#   'View_Count': '730',
#   'Like_Count': '8',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT7M26S',
#   'Thumbnail': 'https://i.ytimg.com/vi/Y3FJceP6MR4/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgyqEfSz3ceLHE1WyWF4AaABAg',
#     'Comment_Text': 'Bro do some vedios ESB',
#     'Comment_Author': '@pavankumar1697',
#     'Comment_PublishedAt': '2023-06-08T12:50:48Z'}}},
#  'Video_Id_6': {'Video_Id': 'dH99q1vBqNQ',
#   'Video_Name': '3. How to create or delete buckets from AWS S3 using Talend l tS3BucketCreate l tS3BucketDelete',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #tS3BucketCreate #tS3BucketDelete\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'creating multiple tasks in Talend cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3bucketcreate',
#    'ts3bucketdelete',
#    'ts3bucketexist'],
#   'PublishedAt': '2023-05-10T04:00:17Z',
#   'View_Count': '301',
#   'Like_Count': '4',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT7M22S',
#   'Thumbnail': 'https://i.ytimg.com/vi/dH99q1vBqNQ/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugxdgccal-fh4ZSIOcN4AaABAg',
#     'Comment_Text': 'Useful video',
#     'Comment_Author': '@jbkhan1920',
#     'Comment_PublishedAt': '2023-09-04T18:29:48Z'}}},
#  'Video_Id_7': {'Video_Id': '2FNnLwaacQc',
#   'Video_Name': '2. How to check whether bucket exists in S3 using tS3BucketExist Component l tS3BucketExist l Talend',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n\n\n#S3Components #Talend #tS3BucketExist\n\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\n\nIf you have any doubts then please drop a comment\n\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'creating multiple tasks in Talend cloud',
#    'promoting jobs to Talend Cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3',
#    'ts3BucketExist'],
#   'PublishedAt': '2023-05-03T03:30:00Z',
#   'View_Count': '353',
#   'Like_Count': '5',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT5M55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/2FNnLwaacQc/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_8': {'Video_Id': 'Bqypojx4knM',
#   'Video_Name': '1. How to make a S3 Connection using Talend components l ts3Connection l Talend l AWS S3 Components',
#   'Video_Description': '#####Talend AWS Tutorials####\n\n#S3Components #Talend #ts3Connection\n\nThis tutorial session covers about various talend components related to AWS S3 and how to work with them from talend.\n\nIf you have any doubts then please drop a comment\n\nIf you want to learn the below topics, watch the video content related to those on this channel\n\nWatch SQL Here\nhttps://www.youtube.com/watch?v=afASFV_LdLU&list=PLOr008ImHvfaW9fL4VYNClXIRLk2jllQF\n\nWatch Tableau Here\nhttps://www.youtube.com/watch?v=Ff2RmyZTUlQ&list=PLOr008ImHvfayAjY9W0jlvXeinugl5k2w\n\nWatch Talend Here\nhttps://www.youtube.com/watch?v=9xKnho2veHU&list=PLOr008ImHvfan_fuDr5RVyexpeYJAp9FX\n\nWatch VBA Programming Here\nhttps://www.youtube.com/watch?v=yMj0AvWD_CY&list=PLOr008ImHvfYqQSZ_hyJ6hMbYg7mE1DKd\n\n------------------OR--------------------\nPlease subscribe and share the channel.\n\n## Thank You ##',
#   'Tags': ['Talend Data Integration',
#    'Talend Big Data',
#    'How to install Talend from Talend Cloud',
#    'Creating Github repository',
#    'scheduling jobs in cloud',
#    'execution plan in cloud',
#    'creating tasks',
#    'creating multiple tasks in Talend cloud',
#    'promoting jobs to Talend Cloud',
#    'creating Environments',
#    'creating workspaces',
#    'workspaces permissions',
#    'creating users',
#    'creating groups',
#    'adding projects',
#    'Talend AWS S3',
#    'S3 components',
#    'ts3connection',
#    'ts3get',
#    'ts3put',
#    'ts3archive',
#    'ts3copy',
#    'talend with aws s3'],
#   'PublishedAt': '2023-03-28T02:00:03Z',
#   'View_Count': '1291',
#   'Like_Count': '10',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '5',
#   'Duration': 'PT8M10S',
#   'Thumbnail': 'https://i.ytimg.com/vi/Bqypojx4knM/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgxeUpQXuOKkUmWeZS54AaABAg',
#     'Comment_Text': 'Hi,can you make videos on AWS redshift,pls',
#     'Comment_Author': '@sudhakarkunchala7928',
#     'Comment_PublishedAt': '2023-10-13T19:30:27Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgziJnNlC3RnckaDxJh4AaABAg',
#     'Comment_Text': 'Hi,can we make video on snowflake',
#     'Comment_Author': '@sudhakarkunchala7928',
#     'Comment_PublishedAt': '2023-10-07T13:10:03Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgyOVCBmJENvNSNUcvV4AaABAg',
#     'Comment_Text': 'P R O M O S M ☹️',
#     'Comment_Author': '@joanenunemaker3018',
#     'Comment_PublishedAt': '2023-05-03T16:43:34Z'},
#    'Comment_Id_3': {'Comment_Id': 'Ugxv5old3nFhDOTzNa14AaABAg',
#     'Comment_Text': 'Waiting for more videos',
#     'Comment_Author': '@bharaththalladi8756',
#     'Comment_PublishedAt': '2023-04-06T05:06:10Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgyJ5zQF3bkV20ZKJup4AaABAg',
#     'Comment_Text': 'Thanks for the Video. Could you please explain, if the TOS you have used in this video is on premise or cloud version. How do we differentiate the on-premise version and cloud version.',
#     'Comment_Author': '@subramanyams3742',
#     'Comment_PublishedAt': '2023-04-03T18:23:03Z'}}},
#  'Video_Id_9': {'Video_Id': 'bkfjtbD7wq8',
#   'Video_Name': 'My Colorado Travel Vlog l Colorado l Rocky Mountains l Denver l Trip with Friends',
#   'Video_Description': '#colorado #rockymountains #tripwithfriends #riverrafting #denver \n\nText Credits: Koushal Tata\nVideo/Audio Credits: Venkata Subba Rao Inti\nEditing Credits: Venkata Subba Rao Inti\n\nDay1 at Orlando Video Link:\nhttps://youtu.be/KSMhmMZWmU0\n\nDay2 at Miami Video Link:\nhttps://youtu.be/m__G1wRN4LA\n\nPlease comment down your suggestions for vlogs.\n\n------------------OR--------------------\n\nIf you have any queries, please leave a comment. I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\nThank You',
#   'Tags': ['Colorado Travel Vlog',
#    'Colorado',
#    'Nature vlogs',
#    'trekking',
#    'hiking',
#    'rocky mountains',
#    'life',
#    'maroon bells',
#    'albetta falls',
#    'aspen',
#    'denver downtown',
#    'denver',
#    'boulder',
#    'pikes peak',
#    'cog railway',
#    'royal gorge bridge',
#    'riverrafting',
#    'glenwood springs',
#    'estes park',
#    'tramway',
#    'trip with friends',
#    'us masters trip',
#    'us colorado trip',
#    'travel vlog',
#    'mountains',
#    'hills',
#    'colorado vlog',
#    'university of denver colorado'],
#   'PublishedAt': '2022-10-05T04:15:02Z',
#   'View_Count': '549',
#   'Like_Count': '28',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '17',
#   'Duration': 'PT20M2S',
#   'Thumbnail': 'https://i.ytimg.com/vi/bkfjtbD7wq8/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugx4iPflQcLWCr6ku-N4AaABAg',
#     'Comment_Text': 'Hi bro,  can you post Talend interview questions as a tester and Developer or Link',
#     'Comment_Author': '@ruthwikdatta2709',
#     'Comment_PublishedAt': '2023-03-03T21:55:36Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugw1_oRSxWdpCFXeokZ4AaABAg',
#     'Comment_Text': 'Very nice!',
#     'Comment_Author': '@srinivaastbl8358',
#     'Comment_PublishedAt': '2022-11-27T01:09:29Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgzcIhnbPwJ89IiSDVh4AaABAg',
#     'Comment_Text': 'Awesome',
#     'Comment_Author': '@karthikgolagani6844',
#     'Comment_PublishedAt': '2022-10-17T04:00:11Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgzwZhzUJknprH2NblF4AaABAg',
#     'Comment_Text': 'New supporters from palawan philippines full pack☺️ ❤️',
#     'Comment_Author': '@madzdiary',
#     'Comment_PublishedAt': '2022-10-05T16:31:11Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgxyvzjNzFovQ-XbiMV4AaABAg',
#     'Comment_Text': 'Subbulu…mi gang lo ammailu not allowed ha😅',
#     'Comment_Author': '@mounikachinnabandhyala5653',
#     'Comment_PublishedAt': '2022-10-05T15:08:28Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgweB6yH5lP9U-b-Xdl4AaABAg',
#     'Comment_Text': 'Anna, nannu kuda me frnds group lo join cheskova pleazzzz😊😊',
#     'Comment_Author': '@eeshwarasai',
#     'Comment_PublishedAt': '2022-10-05T05:39:34Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgzReXt5k1J-cGBtowh4AaABAg',
#     'Comment_Text': 'Big fan of your videos anna, keep going. \nOne word #KCPD. 🔥🔥',
#     'Comment_Author': '@chaitanyasrinivasvuyyuri8355',
#     'Comment_PublishedAt': '2022-10-05T05:32:23Z'},
#    'Comment_Id_7': {'Comment_Id': 'Ugx6RcK5lxt-Jnb5K5Z4AaABAg',
#     'Comment_Text': '😊👌🏼',
#     'Comment_Author': '@ktinti6794',
#     'Comment_PublishedAt': '2022-10-05T05:22:51Z'},
#    'Comment_Id_8': {'Comment_Id': 'UgxxKzFOyIvUVGDEfp54AaABAg',
#     'Comment_Text': 'Waiting for 2nd vlog in colorado series',
#     'Comment_Author': '@bharaththalladi8756',
#     'Comment_PublishedAt': '2022-10-05T05:15:30Z'},
#    'Comment_Id_9': {'Comment_Id': 'Ugxb9y3O2gbi5sYD2QZ4AaABAg',
#     'Comment_Text': '❤ ❤',
#     'Comment_Author': '@saimukesh3848',
#     'Comment_PublishedAt': '2022-10-05T04:55:49Z'},
#    'Comment_Id_10': {'Comment_Id': 'Ugyo37F167nIZg9H_zx4AaABAg',
#     'Comment_Text': '❤🔥🔥',
#     'Comment_Author': '@manojvarma9544',
#     'Comment_PublishedAt': '2022-10-05T04:53:02Z'},
#    'Comment_Id_11': {'Comment_Id': 'UgyOnHGATWnUlFKZuTN4AaABAg',
#     'Comment_Text': '👌👌👌',
#     'Comment_Author': '@lakshmanvella4239',
#     'Comment_PublishedAt': '2022-10-05T04:16:43Z'}}},
#  'Video_Id_10': {'Video_Id': 'qP20gRSfzAM',
#   'Video_Name': 'Florida Travel Vlog: Final Day at Keywest & Fort Lauderdale l SkyDiving l Everglades l Palm Beach',
#   'Video_Description': '#palmbeach  #evergladesnationalpark  #skydiving  #fortlauderdale #keywest \n\nVideo/Audio Credits: Venkata Subba Rao Inti\nEditing Credits: Venkata Subba Rao Inti\n\nDay1 at Orlando Video Link:\nhttps://youtu.be/KSMhmMZWmU0\n\nDay2 at Miami Video Link:\nhttps://youtu.be/m__G1wRN4LA\n\nThis is the final day of our 5 day trip to florida. We have covered Keywest and Fort Lauderdale. \n\nPlease comment down your suggestions for vlogs.\n\nMy LinkedIn Account:\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nBlogspot:\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any queries, please leave a comment. I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\nThank You',
#   'Tags': ['Florida Trip',
#    'trip with friends',
#    'umkc students florida trip',
#    'kansas city airport',
#    'kansas city to florida',
#    'skydiving',
#    'palm beach',
#    'cognitive hub',
#    'cognitive hub vlogs',
#    'keywest',
#    'aligators',
#    'everglades aligators park',
#    'keywest skydiving',
#    'friends vlog',
#    'keywest beaches',
#    'southernmost part of usa',
#    'subbu vlogs',
#    'higgs beach',
#    'spring break',
#    'best sunset in keywest',
#    'water rides at keywest',
#    'rapid park',
#    'florida vlogs',
#    'keywest vlogs',
#    'everglades safari park',
#    'florida life',
#    'florida',
#    'USA Vlogs'],
#   'PublishedAt': '2022-06-17T00:15:02Z',
#   'View_Count': '514',
#   'Like_Count': '26',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '3',
#   'Duration': 'PT14M37S',
#   'Thumbnail': 'https://i.ytimg.com/vi/qP20gRSfzAM/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgzRvWGgAMSNF4nbiYl4AaABAg',
#     'Comment_Text': "Hi. I'm learning talend CI CD pipeline. Need guidance. How can i contact you?",
#     'Comment_Author': '@akshayandindu',
#     'Comment_PublishedAt': '2022-08-01T12:29:34Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgxeH_vSStELRyK2rml4AaABAg',
#     'Comment_Text': 'Now why dont you hype them up with the  upcoming trip bruhhh. #Colorado',
#     'Comment_Author': '@sdklktb',
#     'Comment_PublishedAt': '2022-06-17T19:39:28Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgwcUr-ot0O68kq7CsJ4AaABAg',
#     'Comment_Text': '👏👏',
#     'Comment_Author': '@ktinti6794',
#     'Comment_PublishedAt': '2022-06-17T07:50:59Z'}}},
#  'Video_Id_11': {'Video_Id': 'm__G1wRN4LA',
#   'Video_Name': 'Florida Travel Vlog: Day2 at Miami l Bayside View l Wynwood Walls l South Miami Beach l Florida',
#   'Video_Description': '#TravelVlog #wynwood #miami  #TripWithFriends \n\nVideo/Audio Credits: Venkata Subba Rao Inti\nEditing Credits: Venkata Subba Rao Inti\n\nDay1 at Orlando Video Link:\nhttps://youtu.be/KSMhmMZWmU0\n\nIn this video, I have shown what we have done on the second day of our trip to Florida. In the next coming videos, I am going to show you what we did in Keywest. \n\nPlease comment down your suggestions for vlogs.\n\nMy LinkedIn Account:\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nBlogspot:\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any queries, please leave a comment. I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\nThank You',
#   'Tags': ['Florida Trip',
#    'miami',
#    'universal studios',
#    'trip with friends',
#    'umkc',
#    'umkc students florida trip',
#    'miami beaches',
#    'kansas city airport',
#    'kansas city to florida',
#    'skydiving',
#    'palm beach',
#    'cognitive hub',
#    'cognitive hub vlogs',
#    'bayside view',
#    'keywest',
#    'aligators',
#    'everglades aligators park',
#    'keywest skydiving',
#    'friends vlog',
#    'keywest beaches',
#    'southernmost part of usa',
#    'subbu vlogs',
#    'wynwood walls',
#    'south miami beach',
#    'bayside boating',
#    'florida boating',
#    'miami boating',
#    'miami downtown',
#    'south pier park'],
#   'PublishedAt': '2022-06-10T12:30:12Z',
#   'View_Count': '555',
#   'Like_Count': '43',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '8',
#   'Duration': 'PT11M43S',
#   'Thumbnail': 'https://i.ytimg.com/vi/m__G1wRN4LA/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgxTdT1qf-Pq1lzaB9F4AaABAg',
#     'Comment_Text': 'Keep it up 💙',
#     'Comment_Author': '@manadeidantha6544',
#     'Comment_PublishedAt': '2022-11-29T16:04:33Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgzYPf8YHK_qu1rwRMF4AaABAg',
#     'Comment_Text': 'Hi Nani happy to see you over there',
#     'Comment_Author': '@satyanarayanamurthytalala5614',
#     'Comment_PublishedAt': '2022-06-19T17:28:14Z'},
#    'Comment_Id_2': {'Comment_Id': 'Ugx_PF7XC-dkH2kK0ft4AaABAg',
#     'Comment_Text': 'Hiiii..Nice video bro.. 😘',
#     'Comment_Author': '@VinayKumar-bu9kp',
#     'Comment_PublishedAt': '2022-06-11T23:56:15Z'},
#    'Comment_Id_3': {'Comment_Id': 'Ugxk3pZprerx7t1Up_h4AaABAg',
#     'Comment_Text': 'Nice video😄',
#     'Comment_Author': '@balajibalu335',
#     'Comment_PublishedAt': '2022-06-11T08:09:28Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugy_c4tEdf1R-08GQEl4AaABAg',
#     'Comment_Text': 'If you are still in Florida, the Treasure Coast is awaiting your visit. Hit us up when you head this way.',
#     'Comment_Author': '@thegallivanthropologists',
#     'Comment_PublishedAt': '2022-06-11T00:47:57Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgwNTXSCY7LvwNUKHt54AaABAg',
#     'Comment_Text': 'kinda mida upu ma subbu anna toppu',
#     'Comment_Author': '@manideepr4604',
#     'Comment_PublishedAt': '2022-06-10T18:57:59Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgxGXC6Xw-jwhj1Y0tp4AaABAg',
#     'Comment_Text': 'Nice video Bro 🙂',
#     'Comment_Author': '@ktinti6794',
#     'Comment_PublishedAt': '2022-06-10T13:17:45Z'},
#    'Comment_Id_7': {'Comment_Id': 'Ugw-2307gS9P35FOcnF4AaABAg',
#     'Comment_Text': 'Nice ra 👌',
#     'Comment_Author': '@lakshmanvella4239',
#     'Comment_PublishedAt': '2022-06-10T12:31:30Z'}}},
#  'Video_Id_12': {'Video_Id': 'KSMhmMZWmU0',
#   'Video_Name': 'Florida Trip Vlog: First Part at Orlando l Iconic Park l Daytona Beach l Florida l Trip with Friends',
#   'Video_Description': '#TravelVlog #FloridaVlogs #Orlando #TripWithFriends\n\nVideo/Audio Credits: Venkata Subba Rao Inti\nEditing Credits: Venkata Subba Rao Inti\n\nIn this video, I have shown what we have done on the first day of our trip to Florida. In the next coming videos, I am going to show you what we did in Miami and Keywest. \n\nPlease comment down your suggestions for vlogs.\n\nMy LinkedIn Account:\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nBlogspot:\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any queries, please leave a comment. I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\nThank You',
#   'Tags': ['Florida Trip',
#    'Daytona beach',
#    'miami',
#    'orlando',
#    'universal studios',
#    'orlando iconic park',
#    'trip with friends',
#    'umkc',
#    'umkc students florida trip',
#    'miami beaches',
#    'orlando airport',
#    'kansas city airport',
#    'kansas city to florida',
#    'skydiving',
#    'palm beach',
#    'cognitive hub',
#    'cognitive hub vlogs',
#    'bayside view',
#    'keywest',
#    'aligators',
#    'everglades aligators park',
#    'keywest skydiving',
#    'friends vlog',
#    'keywest beaches',
#    'southernmost part of usa',
#    'subbu vlogs'],
#   'PublishedAt': '2022-06-03T04:00:12Z',
#   'View_Count': '986',
#   'Like_Count': '90',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '21',
#   'Duration': 'PT10M16S',
#   'Thumbnail': 'https://i.ytimg.com/vi/KSMhmMZWmU0/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugwj_k-zf5PT8EZWGPF4AaABAg',
#     'Comment_Text': 'bro nenu etl abinitio1.5 years experience vundi but nenu talend nerchukundam anukutuna How many days it will take to learn. your tutorials are enough right.',
#     'Comment_Author': '@naveeng1752',
#     'Comment_PublishedAt': '2023-09-30T01:28:12Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgzcvCxam9YqrXhynTh4AaABAg',
#     'Comment_Text': 'nice video anna',
#     'Comment_Author': '@naveeng1752',
#     'Comment_PublishedAt': '2023-09-22T04:24:03Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgxChG15BOcMEhAHP0Z4AaABAg',
#     'Comment_Text': '🎶 p͎r͎o͎m͎o͎s͎m͎',
#     'Comment_Author': '@iwoodward4843',
#     'Comment_PublishedAt': '2022-06-16T08:53:14Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgzX8_jpmWtKmp-Cr7J4AaABAg',
#     'Comment_Text': 'Very nice',
#     'Comment_Author': '@srinivasaraoboddeti7908',
#     'Comment_PublishedAt': '2022-06-12T03:11:54Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugx7cV3xNwoj_gRxWS54AaABAg',
#     'Comment_Text': 'Hii...How are u Naani anna.❔',
#     'Comment_Author': '@VinayKumar-bu9kp',
#     'Comment_PublishedAt': '2022-06-12T00:01:01Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgzPsILzso6IPJssZAh4AaABAg',
#     'Comment_Text': 'Waiting for 2nd vlog',
#     'Comment_Author': '@bharaththalladi5994',
#     'Comment_PublishedAt': '2022-06-03T23:07:13Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgyCtDSbKmWW3OqLFUJ4AaABAg',
#     'Comment_Text': 'Pranay hero',
#     'Comment_Author': '@snehithreddy6506',
#     'Comment_PublishedAt': '2022-06-03T14:26:16Z'},
#    'Comment_Id_7': {'Comment_Id': 'UgzP02Igoz8j86I3P354AaABAg',
#     'Comment_Text': 'Nice location 👌😊',
#     'Comment_Author': '@maheshbandi9905',
#     'Comment_PublishedAt': '2022-06-03T12:31:01Z'},
#    'Comment_Id_8': {'Comment_Id': 'UgyzqhJUtOLo8976CYR4AaABAg',
#     'Comment_Text': 'We will cover next trip',
#     'Comment_Author': '@karranagarajureddy8177',
#     'Comment_PublishedAt': '2022-06-03T09:13:22Z'},
#    'Comment_Id_9': {'Comment_Id': 'Ugx7io586aQPwm4VGQB4AaABAg',
#     'Comment_Text': 'Nenu okadini miss iya mama',
#     'Comment_Author': '@karranagarajureddy8177',
#     'Comment_PublishedAt': '2022-06-03T09:12:43Z'},
#    'Comment_Id_10': {'Comment_Id': 'UgzQFffoPrIzWogTMfN4AaABAg',
#     'Comment_Text': 'Aapka Vlog to bahut achha hai Full Support Ji !\nMain bhi Vlog banata hun dekh kar batayen kaisa hai !',
#     'Comment_Author': '@STAN-he9oy',
#     'Comment_PublishedAt': '2022-06-03T08:13:38Z'},
#    'Comment_Id_11': {'Comment_Id': 'Ugyje3hSI8NTKXM43px4AaABAg',
#     'Comment_Text': 'Nice video😀😄',
#     'Comment_Author': '@balajibalu335',
#     'Comment_PublishedAt': '2022-06-03T08:08:38Z'},
#    'Comment_Id_12': {'Comment_Id': 'Ugxwmev5ujDqIRmA3lJ4AaABAg',
#     'Comment_Text': 'Aapka Vlog to bahut achha hai Full Support Ji\nMain bhi Vlog banata hun dekh kar batayen kaisa hai',
#     'Comment_Author': '@pintukumar14321',
#     'Comment_PublishedAt': '2022-06-03T07:55:15Z'},
#    'Comment_Id_13': {'Comment_Id': 'UgzFp4f4dr-AQjsUzDt4AaABAg',
#     'Comment_Text': 'Aaahaaaa',
#     'Comment_Author': '@manadeidantha6544',
#     'Comment_PublishedAt': '2022-06-03T06:49:15Z'},
#    'Comment_Id_14': {'Comment_Id': 'UgzOr1LttVj6qQjj1gx4AaABAg',
#     'Comment_Text': 'Super bro👏👏🏂🪂🏄',
#     'Comment_Author': '@durgaprasadt7162',
#     'Comment_PublishedAt': '2022-06-03T06:42:29Z'},
#    'Comment_Id_15': {'Comment_Id': 'Ugz0XaMZXLaUb9tTaDB4AaABAg',
#     'Comment_Text': 'Cogintive- unusual . see you on my side! 📢',
#     'Comment_Author': '@eprohoda',
#     'Comment_PublishedAt': '2022-06-03T04:43:46Z'},
#    'Comment_Id_16': {'Comment_Id': 'Ugxq3KLm1unO4k-MDsB4AaABAg',
#     'Comment_Text': 'Babuuuuuuuuu',
#     'Comment_Author': '@tejaravuri2012',
#     'Comment_PublishedAt': '2022-06-03T04:03:38Z'},
#    'Comment_Id_17': {'Comment_Id': 'Ugx4eFBhkrjU5bLP4n94AaABAg',
#     'Comment_Text': 'Super ra😍👏👏',
#     'Comment_Author': '@ktinti6794',
#     'Comment_PublishedAt': '2022-06-03T04:01:44Z'}}},
#  'Video_Id_13': {'Video_Id': 'Ylkwb-N47fg',
#   'Video_Name': '10. How to use the cut command in Linux l Cut l Video-10 l Linux Commands l Cognitive Hub',
#   'Video_Description': '##### Linux Tutorials####\n\n#cut #Linux #LinuxCommands\n\nThis tutorial session covers a few of the Linux Commands that you need to learn in order to fulfill all the goals in the projects. \n\n0:10 Introduction\n1:10 Demonstrating cut command\n\nIf you have any doubts then please drop a message on my LinkedIn page(Link is mentioned below)\n\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nAll the source files will be available at \n\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any doubts,Please leave a comment.I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\n## Thank You ##',
#   'Tags': ['how commands are used in mac os',
#    'how linux commands are used',
#    'linux',
#    'linux commands',
#    'ls',
#    'cd',
#    'mkdir',
#    'linux commands with options',
#    'rm',
#    'rmdir',
#    'touch',
#    'nano',
#    'cp',
#    'move command',
#    'mv',
#    'cut command',
#    'chmod',
#    'head',
#    'tail commands',
#    'mac os commands',
#    'putty commands',
#    'wordcount',
#    'wc',
#    'sort command in linux',
#    'uniq command in linux',
#    'zip',
#    'unzip commands',
#    'history commands',
#    'events in linux comamnds',
#    'windows commands',
#    'bash',
#    'awk',
#    'grep',
#    'foss programs.usage of linux commands',
#    'linux commands with different options'],
#   'PublishedAt': '2022-03-23T04:30:11Z',
#   'View_Count': '269',
#   'Like_Count': '6',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '4',
#   'Duration': 'PT12M42S',
#   'Thumbnail': 'https://i.ytimg.com/vi/Ylkwb-N47fg/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugy9YPQxeHqUljrOzV54AaABAg',
#     'Comment_Text': 'hi friend can you make videos about informatica please :)',
#     'Comment_Author': '@comptegmail273',
#     'Comment_PublishedAt': '2023-02-18T14:17:13Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgwvYFBk9qvtKdNemtF4AaABAg',
#     'Comment_Text': 'Hii bro\n Can I get u r number please',
#     'Comment_Author': '@srinivasareddy4818',
#     'Comment_PublishedAt': '2022-05-19T06:59:04Z'},
#    'Comment_Id_2': {'Comment_Id': 'Ugzc_XcAa1ESnJef4MF4AaABAg',
#     'Comment_Text': 'Please upload videos on Sed, Crontab and NoHup commands',
#     'Comment_Author': '@shaikmahaboob4766',
#     'Comment_PublishedAt': '2022-03-30T07:31:45Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgxVF1Ns6LplyIhqb0d4AaABAg',
#     'Comment_Text': 'Hi Bro',
#     'Comment_Author': '@shaikmahaboob4766',
#     'Comment_PublishedAt': '2022-03-30T07:30:50Z'}}},
#  'Video_Id_14': {'Video_Id': 'j3vnVDK42mY',
#   'Video_Name': '9. How to use head and tail commands in linux l Head l Tail l Linux Commands l Cognitive Hub',
#   'Video_Description': '##### Linux Tutorials####\n\n#Head #Tail #LinuxCommands\n\nThis tutorial session covers a few of the Linux Commands that you need to learn in order to fulfill all the goals in the projects. \n\n0:18 Introduction\n1:24 Demonstrating Head Command\n8:15 Demonstrating Tail Command\n\nIf you have any doubts then please drop a message on my LinkedIn page(Link is mentioned below)\n\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nAll the source files will be available at \n\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any doubts,please leave a comment. I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\n## Thank You ##',
#   'Tags': ['how commands are used in mac os',
#    'how linux commands are used',
#    'linux',
#    'linux commands',
#    'ls',
#    'cd',
#    'mkdir',
#    'linux commands with options',
#    'rm',
#    'rmdir',
#    'touch',
#    'nano',
#    'cp',
#    'move command',
#    'mv',
#    'cut command',
#    'chmod',
#    'head',
#    'tail commands',
#    'mac os commands',
#    'putty commands',
#    'wordcount',
#    'wc',
#    'sort command in linux',
#    'uniq command in linux',
#    'zip',
#    'unzip commands',
#    'history commands',
#    'events in linux comamnds',
#    'windows commands',
#    'bash',
#    'awk',
#    'grep',
#    'foss programs.usage of linux commands',
#    'linux commands with different options'],
#   'PublishedAt': '2022-03-16T04:30:12Z',
#   'View_Count': '151',
#   'Like_Count': '7',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '3',
#   'Duration': 'PT10M55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/j3vnVDK42mY/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgwoeJHeoR4WfJ0zkEF4AaABAg',
#     'Comment_Text': 'SFTP',
#     'Comment_Author': '@shaikmahaboob4766',
#     'Comment_PublishedAt': '2022-03-17T02:01:44Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgzKJs0s8oLjmPWE4114AaABAg',
#     'Comment_Text': 'అందగారు',
#     'Comment_Author': '@pantpanthers227',
#     'Comment_PublishedAt': '2022-03-16T04:36:53Z'},
#    'Comment_Id_2': {'Comment_Id': 'Ugx4GeBM1CImJhEGjsl4AaABAg',
#     'Comment_Text': 'Super super dhummu lepav ra',
#     'Comment_Author': '@manadeidantha6544',
#     'Comment_PublishedAt': '2022-03-16T04:35:12Z'}}},
#  'Video_Id_15': {'Video_Id': 'GT3C4j-NL-I',
#   'Video_Name': '8. How to use grep Command in linux l Video-8 l grep l Linux Commands l Cognitive Hub',
#   'Video_Description': '##### Linux Tutorials####\n\n#grep #Linux #LinuxCommands\n\nThis tutorial session covers few of the Linux Commands that you need to learn in order fulfill all the goals in the projects. \n\n0:18 Introduction\n5:15 Demonstrating grep command\n\nIf you have any doubts then please drop a message in my linkedin page(Link is mentioned below)\n\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nAll the source files will be available at \n\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any doubts,Please leave a comment.I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\n## Thank You ##',
#   'Tags': ['how commands are used in mac os',
#    'how linux commands are used',
#    'linux',
#    'linux commands',
#    'ls',
#    'cd',
#    'mkdir',
#    'linux commands with options',
#    'rm',
#    'rmdir',
#    'touch',
#    'nano',
#    'cp',
#    'move command',
#    'mv',
#    'cut command',
#    'chmod',
#    'head',
#    'tail commands',
#    'mac os commands',
#    'putty commands',
#    'wordcount',
#    'wc',
#    'sort command in linux',
#    'uniq command in linux',
#    'zip',
#    'unzip commands',
#    'history commands',
#    'events in linux comamnds',
#    'windows commands',
#    'bash',
#    'awk',
#    'grep',
#    'foss programs.usage of linux commands',
#    'linux commands with different options'],
#   'PublishedAt': '2022-03-09T05:30:06Z',
#   'View_Count': '122',
#   'Like_Count': '3',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT21M39S',
#   'Thumbnail': 'https://i.ytimg.com/vi/GT3C4j-NL-I/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgyW00dh-K2vKoiUQYd4AaABAg',
#     'Comment_Text': 'Hey hi in Talend I have one date column data format type is string and data like this Wed Feb 09 15:24:49 IST 2022 but in that date column I’m using to create one more column but I need only day in that new column and I need day like Sunday to Saturday full names can you give some idea how to get',
#     'Comment_Author': '@brahmareddy7373',
#     'Comment_PublishedAt': '2022-03-09T13:35:21Z'}}},
#  'Video_Id_16': {'Video_Id': 'EfHACyU3fL0',
#   'Video_Name': '7. How to zip and unzip files/folders in linux l Zip l Unzip l Video-7 l History l Linux Commands',
#   'Video_Description': '##### Linux Tutorials####\n\n#zip #unzip #history #Linux #LinuxCommands\n\nThis tutorial session covers a few of the Linux Commands that you need to learn in order to fulfill all the goals in the projects. \n\n0:14 Introduction\n2:23 Demonstrating zip command\n8:47 Demonstrating unzip command\n15:40 Demonstrating history commands\n\nIf you have any doubts then please drop a message on my LinkedIn page(Link is mentioned below)\n\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nAll the source files will be available at \n\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any doubts, please leave a comment. I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\n## Thank You ##',
#   'Tags': ['how commands are used in mac os',
#    'how linux commands are used',
#    'linux',
#    'linux commands',
#    'ls',
#    'cd',
#    'mkdir',
#    'linux commands with options',
#    'rm',
#    'rmdir',
#    'touch',
#    'nano',
#    'cp',
#    'move command',
#    'mv',
#    'cut command',
#    'chmod',
#    'head',
#    'tail commands',
#    'mac os commands',
#    'putty commands',
#    'wordcount',
#    'wc',
#    'sort command in linux',
#    'uniq command in linux',
#    'zip',
#    'unzip commands',
#    'history commands',
#    'events in linux comamnds',
#    'windows commands',
#    'bash',
#    'awk',
#    'grep',
#    'foss programs.usage of linux commands',
#    'linux commands with different options'],
#   'PublishedAt': '2022-03-02T05:30:04Z',
#   'View_Count': '263',
#   'Like_Count': '8',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT20M29S',
#   'Thumbnail': 'https://i.ytimg.com/vi/EfHACyU3fL0/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugyaufz3jZ47fQP82014AaABAg',
#     'Comment_Text': 'I need talend work support required,let me know are you able to help',
#     'Comment_Author': '@rudraraju2467',
#     'Comment_PublishedAt': '2022-03-03T08:07:19Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgxCKQ418BajuuHkNLN4AaABAg',
#     'Comment_Text': 'Hi bro',
#     'Comment_Author': '@rudraraju2467',
#     'Comment_PublishedAt': '2022-03-03T08:06:35Z'}}},
#  'Video_Id_17': {'Video_Id': 'R-dXzBVL9-A',
#   'Video_Name': '6. How to use sort and uniq commands in Linux l Sort l Uniq l Video-6 l Linux Commands',
#   'Video_Description': '##### Linux Tutorials####\n\n#sort #uniq #Linux #LinuxCommands\n\nThis tutorial session covers a few of the Linux Commands that you need to learn in order to fulfill all the goals in the projects. \n\n0:25 Introduction\n1:33 Demonstrating Sort Command\n8:49 Demonstrating Uniq Command\n\nIf you have any doubts then please drop a message on my LinkedIn page(Link is mentioned below)\n\nhttps://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/\n\nAll the source files will be available at \n\nhttps://cognitivehub2020.blogspot.com/\n\n------------------OR--------------------\n\nIf you have any doubts,Please leave a comment.I will reply back in 48hrs\nAnd also please do subscribe and share the channel.\n## Thank You ##',
#   'Tags': ['how commands are used in mac os',
#    'how linux commands are used',
#    'linux',
#    'linux commands',
#    'ls',
#    'cd',
#    'mkdir',
#    'linux commands with options',
#    'rm',
#    'rmdir',
#    'touch',
#    'nano',
#    'cp',
#    'move command',
#    'mv',
#    'cut command',
#    'chmod',
#    'head',
#    'tail commands',
#    'mac os commands',
#    'putty commands',
#    'wordcount',
#    'wc',
#    'sort command in linux',
#    'uniq command in linux',
#    'zip',
#    'unzip commands',
#    'history commands',
#    'events in linux comamnds',
#    'windows commands',
#    'bash',
#    'awk',
#    'grep',
#    'foss programs.usage of linux commands',
#    'linux commands with different options'],
#   'PublishedAt': '2022-02-23T05:30:02Z',
#   'View_Count': '170',
#   'Like_Count': '4',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT13M1S',
#   'Thumbnail': 'https://i.ytimg.com/vi/R-dXzBVL9-A/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugzht98iLok7n1wbS5F4AaABAg',
#     'Comment_Text': 'Nice content',
#     'Comment_Author': '@bharaththalladi5994',
#     'Comment_PublishedAt': '2022-02-23T05:31:14Z'}}},
#  'Video_Id_18': {'Video_Id': 'JQhTHioajoQ',
# ...
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T16:22:16Z',
#   'View_Count': '81',
#   'Like_Count': '2',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT12M30S',
#   'Thumbnail': 'https://i.ytimg.com/vi/uQbAqAdJ_t0/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_186': {'Video_Id': '60tD4sC2uzs',
#   'Video_Name': 'VBA Do While Vs Do Until Loops l VBA l Excel Programming l Excel Macros',
#   'Video_Description': '#VBADoWhile #VBADoUntil\n#####Excel VBA Programming for Beginners####\n\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4.VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\n\nLectured by: Inti Venkata Subba Rao\n\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': ['VBA programming',
#    'Excel Programming',
#    'Macro code',
#    'How to assign a Macro code',
#    'Inserting button in VBA',
#    'Copying content from worksheet',
#    'Copying content from workbook',
#    'VBA variables',
#    'VBA operators',
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T16:14:38Z',
#   'View_Count': '22',
#   'Like_Count': '0',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT4M52S',
#   'Thumbnail': 'https://i.ytimg.com/vi/60tD4sC2uzs/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_187': {'Video_Id': '0l84yFa477k',
#   'Video_Name': 'VBA For and ForEach Loops l VBA l Excel Programming l Excel Macros',
#   'Video_Description': '#VBAForLoop #VBAForEachLoop\n#####Excel VBA Programming for Beginners####\n\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4.VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\n\nLectured by: Inti Venkata Subba Rao\n\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': ['VBA programming',
#    'Excel Programming',
#    'Macro code',
#    'How to assign a Macro code',
#    'Inserting button in VBA',
#    'Copying content from worksheet',
#    'Copying content from workbook',
#    'VBA variables',
#    'VBA operators',
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T16:10:18Z',
#   'View_Count': '71',
#   'Like_Count': '2',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT13M57S',
#   'Thumbnail': 'https://i.ytimg.com/vi/0l84yFa477k/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_188': {'Video_Id': 'BofFLwQh-Pw',
#   'Video_Name': 'VBA If Else and Select Statements l VBA l Excel Programming l Excel Macros',
#   'Video_Description': '#VBAIfElse #VBASelect\n#####Excel VBA Programming for Beginners####\n\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4.VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\n\nLectured by: Inti Venkata Subba Rao\n\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': ['VBA programming',
#    'Excel Programming',
#    'Macro code',
#    'How to assign a Macro code',
#    'Inserting button in VBA',
#    'Copying content from worksheet',
#    'Copying content from workbook',
#    'VBA variables',
#    'VBA operators',
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T16:01:53Z',
#   'View_Count': '34',
#   'Like_Count': '2',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT15M46S',
#   'Thumbnail': 'https://i.ytimg.com/vi/BofFLwQh-Pw/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_189': {'Video_Id': 'DPLkSL72l1A',
#   'Video_Name': 'VBA Operators and Operands l VBA l Excel Programming l Excel Macros',
#   'Video_Description': '#VBAOperators #VBAOperands #Excel\n\n\n#####Excel VBA Programming for Beginners####\n\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4.VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\n\nLectured by: Inti Venkata Subba Rao\n\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': ['VBA programming',
#    'Excel Programming',
#    'Macro code',
#    'How to assign a Macro code',
#    'Inserting button in VBA',
#    'Copying content from worksheet',
#    'Copying content from workbook',
#    'VBA variables',
#    'VBA operators',
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T15:54:33Z',
#   'View_Count': '155',
#   'Like_Count': '4',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT11M33S',
#   'Thumbnail': 'https://i.ytimg.com/vi/DPLkSL72l1A/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_190': {'Video_Id': 'PvoZN9DchD4',
#   'Video_Name': 'VBA Variables and Data Types I VBA I Excel Programming I Excel Macros',
#   'Video_Description': '#VBA #Variables #VBADatatypes\n#####Excel VBA Programming for Beginners####\n\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\n\nLectured by: Inti Venkata Subba Rao\n\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': '',
#   'PublishedAt': '2020-04-22T15:19:33Z',
#   'View_Count': '93',
#   'Like_Count': '5',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT10M43S',
#   'Thumbnail': 'https://i.ytimg.com/vi/PvoZN9DchD4/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_191': {'Video_Id': '4oCoq8upoSo',
#   'Video_Name': 'VBA Comments, Constants, MsgBox and InputBox I VBA I Excel Programming I Excel Macros',
#   'Video_Description': '#Excel #VBA #ExcelMacros\n##### Excel VBA Programming for Beginners ####\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\nLectured by: Inti Venkata Subba Rao\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': ['VBA programming',
#    'Excel Programming',
#    'Macro code',
#    'How to assign a Macro code',
#    'Inserting button in VBA',
#    'Copying content from worksheet',
#    'Copying content from workbook',
#    'VBA variables',
#    'VBA operators',
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T15:01:05Z',
#   'View_Count': '83',
#   'Like_Count': '4',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT12M34S',
#   'Thumbnail': 'https://i.ytimg.com/vi/4oCoq8upoSo/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_192': {'Video_Id': 'yMj0AvWD_CY',
#   'Video_Name': 'Enabling Developer Option in Excel l VBA l Excel Programming',
#   'Video_Description': '#####Excel VBA Programming for Beginners####\n\nThis video covers about how to Enable Developer Option in Excel. This Tutorial session will teach you all you need to know to get started with programming VBA. This entire VBA Playlist includes:\n\n1.How to Enable Developer Option in Excel\n2.VBA Comments,MsgBox and Input box with Example\n3.VBA Variables and Data Types with Examples\n4VBA Operators and Operands with Examples\n5.VBA If Else and Select Statements with example\n6.VBA For and ForEach Loop with Example\n7.VBA Do While Vs Do Until Loops with Example\n8.VBA Arrays with Examples\n9.VBA Range Objects with Example\n10.VBA String Functions with Examples\n11.VBA Object Model with Example\n12.Copying Content from one worksheet to other worksheet.\n13.Copying Content from one WorkBook to other Workbook.\n14.Adding Breakpoints and Debugging the Macro Code\n15.How to insert Checkbox and assign a Macro Code to CheckBox\n16.How to insert Label and assign a Macro Code to Label\n17.How to insert a Group Box and assign a Macro Code to Group Box\n18.How to insert Radio Button and assign a Macro Code to Radio Button\n19.How to insert Scroll Bar and assign a Macro Code to Scroll Bar.\n\nLectured by: Inti Venkata Subba Rao\n\nIf you have any doubts,please leave a comment in the Comment Session.',
#   'Tags': ['VBA programming',
#    'Excel Programming',
#    'Macro code',
#    'How to assign a Macro code',
#    'Inserting button in VBA',
#    'Copying content from worksheet',
#    'Copying content from workbook',
#    'VBA variables',
#    'VBA operators',
#    'VBA conditional statements',
#    'VBA Loop Statements',
#    'VBA Range Objects',
#    'VBA worksheet objects',
#    'VBA workbook objects',
#    'Enabling developer option',
#    'Learn VBA in easy way',
#    'VBA example with Macro Code'],
#   'PublishedAt': '2020-04-22T14:34:43Z',
#   'View_Count': '243',
#   'Like_Count': '9',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT7M19S',
#   'Thumbnail': 'https://i.ytimg.com/vi/yMj0AvWD_CY/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}}}

# %%
ip = input("Enter Channel ID")
y = getChannel(ip)
y


#Channel Name : Lime Guru
#Channel ID : UCHD0rnMSRHWVmn3XqNeXipQ
# Out:
# Enter Channel ID UCHD0rnMSRHWVmn3XqNeXipQ
# {'Channel_Name': {'channel_name': 'LimeGuru',
#   'channel_id': 'UCHD0rnMSRHWVmn3XqNeXipQ',
#   'subscription_count': '10200',
#   'channel_views': '868778',
#   'channel_description': 'Deep dive technical sessions and tutorial for beginners. You can learn latest technologies in detail and easy to understand language. Some of the tutorial include \n\nBig data tutorial\nSpark tutorial\nSpark streaming tutorial\nApache kafka tutorial\nApache airflow tutorial\nMicroservices tutorial\nJava tutorial\nPython tutorial\nMany more to come....',
#   'playlists': 'UUHD0rnMSRHWVmn3XqNeXipQ'},
#  'Video_Id_1': {'Video_Id': 'G9RY23vmV00',
#   'Video_Name': 'Docker Image Digests - Learn In 7 Minutes | Docker Image Hashes And Digests Explained',
#   'Video_Description': 'In this session you will learn the concept of Docker image digests and Docker image hashes, how Docker digests are useful and why do they exist.\n\n#docker #cloud',
#   'Tags': ['docker digests',
#    'docker hashes',
#    'docker Image hashes',
#    'docker Image digests',
#    'docker',
#    'Cloud'],
#   'PublishedAt': '2021-12-20T11:13:13Z',
#   'View_Count': '1112',
#   'Like_Count': '25',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT7M29S',
#   'Thumbnail': 'https://i.ytimg.com/vi/G9RY23vmV00/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgwEc5YhRwApOtPR_rR4AaABAg',
#     'Comment_Text': 'Just what I was looking for! Thank you! I had installed latest tensorflow image on my university server but there were other "latest" tensorflow images with the latest image made 2 weeks earlier. Checking the digests to find a match from tensorflow dockerhub\'s latest image digest was the solution.\nBtw, I think there is a typo in the command. It should be: "docker image ls --digests myimage"',
#     'Comment_Author': '@kaverianuranjana9787',
#     'Comment_PublishedAt': '2022-06-13T15:34:27Z'}}},
#  'Video_Id_2': {'Video_Id': 'ulGsYjxuMHk',
#   'Video_Name': 'Docker Image Layers - Learn In 8 Minutes | How Docker Creates Layers In Docker Images',
#   'Video_Description': 'In this session you will learn the concept of Docker layers in Docker images, how Docker creates different layers from Docker file, Docker layer stacking concepts and why Docker layers are useful.\n\n#docker #cloud',
#   'Tags': ['docker',
#    'Cloud',
#    'Container',
#    'docker Image',
#    'dockerfile',
#    'docker tutorial',
#    'docker Image layers',
#    'learn Docker'],
#   'PublishedAt': '2021-12-20T11:12:38Z',
#   'View_Count': '2992',
#   'Like_Count': '47',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '3',
#   'Duration': 'PT8M29S',
#   'Thumbnail': 'https://i.ytimg.com/vi/ulGsYjxuMHk/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgwNz4Rjnr_PY8eMnjt4AaABAg',
#     'Comment_Text': 'Thanks. You explained it really well.',
#     'Comment_Author': '@naveenhv82',
#     'Comment_PublishedAt': '2023-05-18T13:43:30Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgyYYg5mZQHYphp0JmR4AaABAg',
#     'Comment_Text': 'Thanks. Its explained really well.',
#     'Comment_Author': '@dmytroshchotkin2939',
#     'Comment_PublishedAt': '2022-04-20T15:54:55Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgzbLlSepjHch1xpoJl4AaABAg',
#     'Comment_Text': 'Perfectly Explained! Thank you bhai',
#     'Comment_Author': '@lifeinasmr8619',
#     'Comment_PublishedAt': '2022-04-04T20:28:12Z'}}},
#  'Video_Id_3': {'Video_Id': 'O5e_o1H3uVc',
#   'Video_Name': 'Learn Hadoop YARN Resource Manager In 20 Minutes | Yarn Tutorial For Beginners',
#   'Video_Description': 'In this session you will learn about basics of Hadoop yarn resource manager, yarn components, yarn architecture, yarn resource manager, yarn application manager,yarn scheduler, node manager, application master and container.\n\n#yarn #hadoop #bigdata',
#   'Tags': ['yarn', 'Hadoop', 'resource manager', 'yarn Scheduler'],
#   'PublishedAt': '2021-12-16T10:35:58Z',
#   'View_Count': '4232',
#   'Like_Count': '89',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '8',
#   'Duration': 'PT23M52S',
#   'Thumbnail': 'https://i.ytimg.com/vi/O5e_o1H3uVc/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugz7zFj7g2GqQHDVpZN4AaABAg',
#     'Comment_Text': 'Nicely done <3 Simple and clear! Thank you!',
#     'Comment_Author': '@user-wd5tf8gj7b',
#     'Comment_PublishedAt': '2023-06-12T09:09:29Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugz7Q8XmsiZbtjO2vTl4AaABAg',
#     'Comment_Text': 'Really very good explanation',
#     'Comment_Author': '@suresh.suthar.1251',
#     'Comment_PublishedAt': '2023-03-18T03:42:54Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgyPhB-WuNwqK7cz9sl4AaABAg',
#     'Comment_Text': 'What happens if the node containing the Application master fails? Does it mean the whole Job  fails because it is the one managing the tasks in other containers',
#     'Comment_Author': '@silasphoshoko5511',
#     'Comment_PublishedAt': '2022-10-05T10:48:52Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgwvXbQMvT49-hnWGjh4AaABAg',
#     'Comment_Text': 'Helpful',
#     'Comment_Author': '@bharathkumar-rh4df',
#     'Comment_PublishedAt': '2022-06-23T18:44:15Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgzEqPn5nmCwFQJNePh4AaABAg',
#     'Comment_Text': 'This was brilliant ! One of the best of youtube in YARN tutorials! Post more hadoop internal concepts please.',
#     'Comment_Author': '@42Siren',
#     'Comment_PublishedAt': '2022-04-13T13:49:40Z'},
#    'Comment_Id_5': {'Comment_Id': 'Ugwfivu2a_PQ8xQjHXV4AaABAg',
#     'Comment_Text': 'I have gone through one session of bucketing and partion,I got Full Clarity now... awesome brother...🤝🤝🤝🤝🤝much appreciated...do more videos on bigdata technologies please',
#     'Comment_Author': '@chandramamillapalli984',
#     'Comment_PublishedAt': '2022-01-28T20:47:42Z'},
#    'Comment_Id_6': {'Comment_Id': 'Ugydx5pdBjP1tK5uvp54AaABAg',
#     'Comment_Text': 'Hi brother, your explanation is simply awesome..I am requesting you to do more videos on bigdata, because now a days bigdata has much scope in industry.please do more videos on bigdata technologies from scratch.(hive , sqoop, apache airflow,Kafka,scala,spark,pyspark)',
#     'Comment_Author': '@chandramamillapalli984',
#     'Comment_PublishedAt': '2022-01-28T20:45:32Z'},
#    'Comment_Id_7': {'Comment_Id': 'UgxWwwCWrMBHRV9f0KF4AaABAg',
#     'Comment_Text': 'nice explanation. Thanks!',
#     'Comment_Author': '@abdulhaitalha5944',
#     'Comment_PublishedAt': '2022-01-17T01:36:29Z'}}},
#  'Video_Id_4': {'Video_Id': '3mrdQSRDmk4',
#   'Video_Name': 'Learn AWS LIGHTSAIL In 12 Minutes | AWS LIGHTSAIL Tutorial For Beginners',
#   'Video_Description': 'You will learn AWS LIGHTSAIL in this session including what is AWS LIGHTSAIL, when to use AWS LIGHTSAIL, aws LIGHTSAIL features, aws LIGHTSAIL benefits and more.\n\n#aws #lightsail #cloud',
#   'Tags': ['LightSail', 'AWS', 'Cloud', 'vps', 'limeguru'],
#   'PublishedAt': '2021-12-15T07:04:50Z',
#   'View_Count': '191',
#   'Like_Count': '1',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT12M37S',
#   'Thumbnail': 'https://i.ytimg.com/vi/3mrdQSRDmk4/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_5': {'Video_Id': 'aiesECaegyQ',
#   'Video_Name': 'Learn Jenkins X In 10 Minutes | What Is Jenkins X | Jenkins X Tutorial For Beginners',
#   'Video_Description': 'You will learn about Jenkins X in this video session which covers what is Jenkins x, Jenkins x architecture, Jenkins vs Jenkins x, Jenkins x plugins and extensions, cicd in cloud application etc.\n\n#jenkinsx #cicd #cloud',
#   'Tags': ['Jenkinsx', 'Jenkins', 'cicd', 'cloud', 'docker', 'kubernetes'],
#   'PublishedAt': '2021-10-21T11:49:23Z',
#   'View_Count': '2252',
#   'Like_Count': '24',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT11M47S',
#   'Thumbnail': 'https://i.ytimg.com/vi/aiesECaegyQ/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_6': {'Video_Id': 'QfsXKdm0uys',
#   'Video_Name': 'Learn RabbitMQ In 30 Minutes | RabbitMQ Tutorial In Python For Beginners (Hands-on Tutorial)',
#   'Video_Description': 'This is rabbitmq tutorial for beginners to learn what is rabbitmq, basics of rabbitmq, how to send and receive messages in rabbitmq, how to use rabbitmq for event driven architecture and communication between microservices, how to use rabbitmq for pusblisher subscriber applications. All concepts are explained with hands on code examples in python.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/rabbitmq\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['rabbitmq',
#    'event',
#    'worker',
#    'task',
#    'publisher',
#    'subcriber',
#    'producer',
#    'consumer',
#    'python',
#    'limeguru'],
#   'PublishedAt': '2021-07-05T07:10:22Z',
#   'View_Count': '11958',
#   'Like_Count': '236',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '17',
#   'Duration': 'PT30M37S',
#   'Thumbnail': 'https://i.ytimg.com/vi/QfsXKdm0uys/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgzB-_2XND1DkXHGdZV4AaABAg',
#     'Comment_Text': 'Awesome content!! You explained all the concepts very very well thank you very much! Extremely helpful',
#     'Comment_Author': '@user-bx3ue8tx1i',
#     'Comment_PublishedAt': '2023-07-06T08:14:43Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugw6TZlz8AYQvI9iGd14AaABAg',
#     'Comment_Text': 'Great explain and example.',
#     'Comment_Author': '@futhedude4848',
#     'Comment_PublishedAt': '2023-06-22T02:14:57Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgwgxEuBEXMibpLNqw54AaABAg',
#     'Comment_Text': 'thank you',
#     'Comment_Author': '@odiljondjamalov8965',
#     'Comment_PublishedAt': '2023-05-18T19:39:02Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgwrZdflXf03Axy_dbh4AaABAg',
#     'Comment_Text': 'Great tutorial!',
#     'Comment_Author': '@andrewm4376',
#     'Comment_PublishedAt': '2023-04-11T00:56:49Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgwKynuIYXILTbuYnE14AaABAg',
#     'Comment_Text': 'Complete explanation!\nI just missed the test where both receivers were busy and a new sender sent a new message. 😊',
#     'Comment_Author': '@jotixh',
#     'Comment_PublishedAt': '2023-02-12T17:04:17Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgzYFRJINWh2HjjgbkJ4AaABAg',
#     'Comment_Text': 'Great 👍🏽',
#     'Comment_Author': '@trilliummerge2023',
#     'Comment_PublishedAt': '2023-01-18T07:08:33Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgyADpAuHfD1zhwoAr14AaABAg',
#     'Comment_Text': 'what will happen in case of all the receivers are busy and sender still sends the message to the queue?(when we are setting prefetch_count=1)',
#     'Comment_Author': '@ParthShah-iy4of',
#     'Comment_PublishedAt': '2022-11-28T10:53:17Z'},
#    'Comment_Id_7': {'Comment_Id': 'UgzyNmCrcmnvUYjcYQp4AaABAg',
#     'Comment_Text': 'Very good explanation!! You should make a new video explaining the other approaches of exchanges "Topic" and "Direct"',
#     'Comment_Author': '@ramsescoraspe',
#     'Comment_PublishedAt': '2022-07-27T01:00:41Z'},
#    'Comment_Id_8': {'Comment_Id': 'UgwFjjb9BGs5ai0fJTt4AaABAg',
#     'Comment_Text': "You are great, brother! Thank you. Official examples didn't work for me for some weird reasons (sending worked but not recieving). I've spent almost whole damn day trying to get it working and then when I was really upset and frustrated, I went on YouTube and bumped on your video and it's like magic! I can finally recieve that damn message! Thank you really a lot one more time.",
#     'Comment_Author': '@patmull1',
#     'Comment_PublishedAt': '2022-04-13T16:37:00Z'},
#    'Comment_Id_9': {'Comment_Id': 'Ugz9N1b12HG0m_m6oZx4AaABAg',
#     'Comment_Text': 'I wanted this code badly. Thank you so much',
#     'Comment_Author': '@alan-j',
#     'Comment_PublishedAt': '2022-04-07T19:50:07Z'},
#    'Comment_Id_10': {'Comment_Id': 'UgzqG65QaYQNTcY8WF14AaABAg',
#     'Comment_Text': 'The best explanation on entire internet',
#     'Comment_Author': '@CreatingUtopia',
#     'Comment_PublishedAt': '2022-03-09T02:16:13Z'},
#    'Comment_Id_11': {'Comment_Id': 'UgzihJAXhSEguPxL0Ax4AaABAg',
#     'Comment_Text': 'Superb explanation 😊😊😊',
#     'Comment_Author': '@venkateswarareddypagadala3398',
#     'Comment_PublishedAt': '2021-12-26T15:46:20Z'},
#    'Comment_Id_12': {'Comment_Id': 'UgxoYKSuTV2Q9FdzEF54AaABAg',
#     'Comment_Text': 'Nice explaination 👌🏻 Thankyou!!',
#     'Comment_Author': '@prashantchouksey7030',
#     'Comment_PublishedAt': '2021-12-18T16:23:12Z'},
#    'Comment_Id_13': {'Comment_Id': 'UgzDrHHviNYiUxS4RmJ4AaABAg',
#     'Comment_Text': "Couldn't have been better. Thanks a lot.",
#     'Comment_Author': '@LaeeqKhan01',
#     'Comment_PublishedAt': '2021-09-20T03:52:32Z'},
#    'Comment_Id_14': {'Comment_Id': 'Ugwqs3YQxsb85SZbVER4AaABAg',
#     'Comment_Text': 'Nice Explanation',
#     'Comment_Author': '@brahmaiahchowdarym1913',
#     'Comment_PublishedAt': '2021-07-06T13:41:36Z'}}},
#  'Video_Id_7': {'Video_Id': 'NDehMPl6Vfs',
#   'Video_Name': 'Learn DVC In 20 Minutes | What Is DVC | DVC Tutorial For Beginners (Hands-on Tutorials)',
#   'Video_Description': "This is DVC Tutorial for beginners where you will learn what is dvc, how to build machine learning pipelines using dvc, how to track hyper parameters, machine learning dataset, model artifacts using dvc and how to reproduce machine learning pipelines using DVC and how you can implement mlops using dvc for the model development and tracking lifecycle. We will also learn about caching, DVC Dag's and optimization in DVC using dvc caching.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/dvc\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/",
#   'Tags': ['dvc',
#    'mlops',
#    'machine leraning',
#    'ml',
#    'model',
#    'dataser',
#    'hyperparameter',
#    'experiment',
#    'ml project',
#    'tracking',
#    'dag'],
#   'PublishedAt': '2021-07-02T11:57:51Z',
#   'View_Count': '7335',
#   'Like_Count': '127',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '10',
#   'Duration': 'PT21M53S',
#   'Thumbnail': 'https://i.ytimg.com/vi/NDehMPl6Vfs/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugxvs3GNi-e0jrGA2rd4AaABAg',
#     'Comment_Text': 'dvc run command does not work, and so the example you gave, what command to use now?',
#     'Comment_Author': '@thebboojjaann',
#     'Comment_PublishedAt': '2023-09-05T14:17:17Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgwHHqbh4I3v6caAKdJ4AaABAg',
#     'Comment_Text': 'Thanks for the useful tutorial , Just I fund that with the lates version of dvc there is no run command and we need to use dvc stage add instead of dvc run to create dvc.yaml file',
#     'Comment_Author': '@user-lu3kk8cx6w',
#     'Comment_PublishedAt': '2023-06-29T05:11:52Z'},
#    'Comment_Id_2': {'Comment_Id': 'Ugza6CDiMJjvT_Nn6kR4AaABAg',
#     'Comment_Text': 'Great vid! Thanks so much!',
#     'Comment_Author': '@neelg7736',
#     'Comment_PublishedAt': '2023-05-19T17:10:28Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgxWXSr70yBGaltH_Et4AaABAg',
#     'Comment_Text': 'Thanks for the video. Very informative. Just one question, can you run your commands in vs code, especially on Windows? Is there any tutorial on the setup of the vs code to do that? Thanks.',
#     'Comment_Author': '@VirUsD1221',
#     'Comment_PublishedAt': '2023-03-19T04:28:45Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugw3nUOzI4aZB31lvvp4AaABAg',
#     'Comment_Text': 'Straight forward explanation',
#     'Comment_Author': '@R-Kannada-DevOps',
#     'Comment_PublishedAt': '2023-02-15T18:00:15Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgwOw4AMc9upCwlS_OV4AaABAg',
#     'Comment_Text': 'Thanks for the tutorial',
#     'Comment_Author': '@juliarebrova',
#     'Comment_PublishedAt': '2022-10-23T17:11:18Z'},
#    'Comment_Id_6': {'Comment_Id': 'Ugy5P5ZLdRBvPXL5YUR4AaABAg',
#     'Comment_Text': "Nice video.\n\nBut as I understand it, you don't need to add the initial CSV file as a dependency to the training stage, because the output/filter file has not changed (you changed a temperature from lower than 20 to 9, which also is lower than 20).\nI mean it's expected that training stage will not produce a different result (dvc knows that output/filter has not changed).\n\nOr am I misunderstanding anything?",
#     'Comment_Author': '@FrancoisParmentier',
#     'Comment_PublishedAt': '2022-07-18T09:41:58Z'},
#    'Comment_Id_7': {'Comment_Id': 'Ugy1u_74MWKyPE5DOn94AaABAg',
#     'Comment_Text': 'Nice tutorial',
#     'Comment_Author': '@dipanshupaul1819',
#     'Comment_PublishedAt': '2022-06-24T11:00:29Z'},
#    'Comment_Id_8': {'Comment_Id': 'UgyI_qYEWcN9L2lCqxt4AaABAg',
#     'Comment_Text': 'Helpful',
#     'Comment_Author': '@soubhagyanayak4301',
#     'Comment_PublishedAt': '2021-09-17T03:31:52Z'}}},
#  'Video_Id_8': {'Video_Id': 'IKa7Kx5IQIA',
#   'Video_Name': '[Live Demo] Text To Speech in Python |  Python TTS Library PYTTSX3 | Convert Text To Audio In Python',
#   'Video_Description': 'In this session you will learn how to convert text to speech or audio using python library pyttsx3.\n\nGITHUB CODE URL - \nhttps://github.com/limegurutech/examples/tree/main/python/text-to-speech\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['tts',
#    'pyttsx3',
#    'text to speech',
#    'text to audio',
#    'python',
#    'limeguru'],
#   'PublishedAt': '2021-07-01T12:44:01Z',
#   'View_Count': '1114',
#   'Like_Count': '5',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT3M9S',
#   'Thumbnail': 'https://i.ytimg.com/vi/IKa7Kx5IQIA/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_9': {'Video_Id': 'lPcX2xev0ho',
#   'Video_Name': 'Learn Dask Dataframe In 10 Minutes | Dask Dataframe Tutorial For Beginners (Hands-on Tutorials)',
#   'Video_Description': 'You will learn basics of dask dataframe in python and how dask is different from pandas in python. You will understand with live code how to process dataset in python using dask, how to compute stas, aggregations using dask and achieve parallel processing of big data in python.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/dask-dataframe\n\n#dask #pandas #python\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['dask', 'dataframe', 'python', 'pandas', 'limeguru'],
#   'PublishedAt': '2021-07-01T08:46:33Z',
#   'View_Count': '2268',
#   'Like_Count': '27',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '3',
#   'Duration': 'PT11M5S',
#   'Thumbnail': 'https://i.ytimg.com/vi/lPcX2xev0ho/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugy2AgFzJ9m38trAy2h4AaABAg',
#     'Comment_Text': 'If a single dataframe is huge at that point will dask helps?',
#     'Comment_Author': '@pavantej1776',
#     'Comment_PublishedAt': '2023-07-02T03:20:07Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugw8DHs-5CouFRAcJAh4AaABAg',
#     'Comment_Text': 'Very informative video. Thank you for sharing.',
#     'Comment_Author': '@pollypravir5378',
#     'Comment_PublishedAt': '2022-09-28T06:43:40Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgxB1SU4-HBnvQ1Gxyl4AaABAg',
#     'Comment_Text': 'Great Explanation 👏\n Pls do  videos series on dask .\nAnd if u have already done video on dask then pls share the playlist link.\nThanks😊',
#     'Comment_Author': '@abhishekn786',
#     'Comment_PublishedAt': '2022-03-16T15:03:06Z'}}},
#  'Video_Id_10': {'Video_Id': 'PZFiThbuTFg',
#   'Video_Name': '[Live Demo] Query JSON Data In Postgres Database | JSONB Data Type In Postgresql',
#   'Video_Description': 'You will learn how to handle json data in postgres and run queries to fetch json data, specific json attributes and apply filters on json attributes in postgresql.\n\nGITHUB CODE URL \nhttps://github.com/limegurutech/examples/tree/main/postgres/jsonb\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['postgres', 'json', 'jsonb'],
#   'PublishedAt': '2021-06-30T17:55:58Z',
#   'View_Count': '31632',
#   'Like_Count': '544',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '39',
#   'Duration': 'PT12M34S',
#   'Thumbnail': 'https://i.ytimg.com/vi/PZFiThbuTFg/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgzBe-7jjCB1aV7FvXB4AaABAg',
#     'Comment_Text': 'Very Well Explained, Big Thumb for your wonderful effort',
#     'Comment_Author': '@mrkamranumer',
#     'Comment_PublishedAt': '2023-10-16T10:04:23Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgwhywjFaQPBt8O3M_d4AaABAg',
#     'Comment_Text': 'So good introduction for me evaluating MongoDB vs PostgreSQL!!!',
#     'Comment_Author': '@jesuschal3802',
#     'Comment_PublishedAt': '2023-10-07T12:12:37Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgzI3F_is1gZV-V84f14AaABAg',
#     'Comment_Text': 'Thank you!',
#     'Comment_Author': '@DevMule-zd2ty',
#     'Comment_PublishedAt': '2023-09-28T07:26:37Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgzBOJnxTIQscOTIFOd4AaABAg',
#     'Comment_Text': 'Very useful, thanks 👍🏾',
#     'Comment_Author': '@tosin8776',
#     'Comment_PublishedAt': '2023-08-26T07:12:30Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugy6d9tTidHDjF-O9rV4AaABAg',
#     'Comment_Text': 'Thank you very clear information ❤',
#     'Comment_Author': '@rukhanzakaria',
#     'Comment_PublishedAt': '2023-08-11T23:52:05Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgzvDq6CwpXy0Xlytl54AaABAg',
#     'Comment_Text': 'Every one talk about select or insert. But what about modifying multiple values in that json column in a table',
#     'Comment_Author': '@pothurusudheer-mm7jw',
#     'Comment_PublishedAt': '2023-08-08T13:37:46Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgzKGhbVEo6GHx4Zbct4AaABAg',
#     'Comment_Text': 'Why no update? Seems there are issues updating JSON fields with sqlalchemy.',
#     'Comment_Author': '@yomajo',
#     'Comment_PublishedAt': '2023-02-01T11:45:24Z'},
#    'Comment_Id_7': {'Comment_Id': 'UgwRqLIjZAl7UcKlSl54AaABAg',
#     'Comment_Text': "error: operator does not exist: jsonb[] -> unknown \n\nI'm getting this error at position of (->) how do i resolve it",
#     'Comment_Author': '@BCESivaneshan',
#     'Comment_PublishedAt': '2023-01-12T07:10:12Z'},
#    'Comment_Id_8': {'Comment_Id': 'Ugz-Cz5m7QRwKxGqfx14AaABAg',
#     'Comment_Text': '🤩',
#     'Comment_Author': '@ramprasad5204',
#     'Comment_PublishedAt': '2023-01-11T06:47:39Z'},
#    'Comment_Id_9': {'Comment_Id': 'Ugw1wPQAZcv5s3qfomZ4AaABAg',
#     'Comment_Text': 'What if i want the value of hobby in below json?? Suppose the table name is table1 and column name is emp_details.\n\n{\n        "name" : "John",\n        "age" : "25",\n        "details" : [\n                {\n                        "city" : "Hyderabad",\n                        "plot" : "444",\n                        "hobby" : "Cricket"\n                 }\n         ]\n}',
#     'Comment_Author': '@sanchitshrivastava3402',
#     'Comment_PublishedAt': '2022-12-04T23:41:13Z'},
#    'Comment_Id_10': {'Comment_Id': 'Ugzps-U8u4tpe2EJXgN4AaABAg',
#     'Comment_Text': "Thanks for the video. And how to use the LIKE operator for json. For example, I need to find all entries starting with 'J%' in jsonb.",
#     'Comment_Author': '@Leonardo-gd2iz',
#     'Comment_PublishedAt': '2022-12-01T21:27:14Z'},
#    'Comment_Id_11': {'Comment_Id': 'UgxSr4zSy0qhptshZJF4AaABAg',
#     'Comment_Text': 'Огонь! 🔥',
#     'Comment_Author': '@Leonardo-gd2iz',
#     'Comment_PublishedAt': '2022-12-01T10:04:17Z'},
#    'Comment_Id_12': {'Comment_Id': 'Ugw1ZmFhgKIxSYh-37d4AaABAg',
#     'Comment_Text': 'Here I found what I needed. useful video',
#     'Comment_Author': '@basheerraad5570',
#     'Comment_PublishedAt': '2022-10-13T12:21:39Z'},
#    'Comment_Id_13': {'Comment_Id': 'UgyqxexgvEj63cXtV494AaABAg',
#     'Comment_Text': 'Using  CDL.ToJSONArray, Ive a json array string after reading csv file, . How to use this to insert into a table in postgres?',
#     'Comment_Author': '@sushmithachavanchavan2847',
#     'Comment_PublishedAt': '2022-09-21T11:26:30Z'},
#    'Comment_Id_14': {'Comment_Id': 'UgzXldQ6syRC4PYjA414AaABAg',
#     'Comment_Text': 'i have json file of 20000 data, how do i import them all in the postgres??',
#     'Comment_Author': '@sumanthsz7505',
#     'Comment_PublishedAt': '2022-08-09T06:27:12Z'},
#    'Comment_Id_15': {'Comment_Id': 'UgzGQEWHOZk5Td5HNWZ4AaABAg',
#     'Comment_Text': 'simple and straight :)',
#     'Comment_Author': '@labanidas4318',
#     'Comment_PublishedAt': '2022-08-05T13:32:05Z'},
#    'Comment_Id_16': {'Comment_Id': 'UgxcUURPA-zIuYfuBOp4AaABAg',
#     'Comment_Text': 'Thats really awesome. Thanks. There should be array of objects filtering as well',
#     'Comment_Author': '@salmankashfy',
#     'Comment_PublishedAt': '2022-07-28T15:25:20Z'},
#    'Comment_Id_17': {'Comment_Id': 'UgzR9rQxYc0yHzYKJ8R4AaABAg',
#     'Comment_Text': 'Excellent and to the point',
#     'Comment_Author': '@iGautamGarg',
#     'Comment_PublishedAt': '2022-07-22T07:55:44Z'},
#    'Comment_Id_18': {'Comment_Id': 'UgzxkE6oEpu28YjpuNh4AaABAg',
#     'Comment_Text': 'how to update if I have jsonb object like \'[1,"abac",3,4]\' can you please help. I wan to replace some value inside the list',
#     'Comment_Author': '@jayachandraB',
#     'Comment_PublishedAt': '2022-07-21T08:56:26Z'},
#    'Comment_Id_19': {'Comment_Id': 'UgyhWPDOMcdehYF1yxh4AaABAg',
#     'Comment_Text': 'Simple and clear explanation !!! Good examples !!! Thanks :-)',
#     'Comment_Author': '@vc7057',
#     'Comment_PublishedAt': '2022-07-08T21:20:51Z'}}},
#  'Video_Id_11': {'Video_Id': '6e-ca_L2Qyk',
#   'Video_Name': '[Live Demo] Checkpointing In Spark Streaming | Fault Tolerance & Recovering From Failure In Spark',
#   'Video_Description': 'You will learn how to implement spark checkpointing feature in spark streaming job and how to make you spark streaming jobs fault tolerant. This feature is extremely helpful if you want to recover from failure in your spark jobs.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/spark/spark-streaming-checkpointing\n\nRead KAFKA message in spark job:\nhttps://youtu.be/FEJ9BOTusME\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['checkpointing',
#    'spark streaming',
#    'spark',
#    'fault tolerance',
#    'failover',
#    'big data',
#    'kafka',
#    'limeguru'],
#   'PublishedAt': '2021-06-30T11:14:07Z',
#   'View_Count': '3219',
#   'Like_Count': '39',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '7',
#   'Duration': 'PT10M26S',
#   'Thumbnail': 'https://i.ytimg.com/vi/6e-ca_L2Qyk/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugy3Fojn16UyO_d23IR4AaABAg',
#     'Comment_Text': 'NICE SIR',
#     'Comment_Author': '@tanushreenagar3116',
#     'Comment_PublishedAt': '2023-06-02T18:30:27Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgzCDWP_gIoGFHuE8XJ4AaABAg',
#     'Comment_Text': 'I have done exactly as you shown in video but my batch count and table is not displaying can you please help me with it',
#     'Comment_Author': '@Tarun_Vlogs-ks2fe',
#     'Comment_PublishedAt': '2023-04-24T04:26:41Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgzM2uZewb13JGRqJxB4AaABAg',
#     'Comment_Text': 'What IDE you have used to run this project',
#     'Comment_Author': '@Tarun_Vlogs-ks2fe',
#     'Comment_PublishedAt': '2023-04-24T00:08:26Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgxZ7e6TJZwdOHMwv6V4AaABAg',
#     'Comment_Text': "When we read messages from Kafka and write it to delta table , how to tackle the problem when we have a mix of messages with 2 different schema in Kafka topic. eg: total offset scanned in checkpoint's offset folder is 0 to 50. But 0-10 has old schema and 11-50 has a new schema. How tackle  this kind of situation without cleaning up checkpoint(as this is not always possible on prod env)",
#     'Comment_Author': '@ManishaSingh-cg2jv',
#     'Comment_PublishedAt': '2022-12-30T12:02:51Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugzk9PN6WI0UsRNcoCZ4AaABAg',
#     'Comment_Text': 'Thanks amazing video',
#     'Comment_Author': '@tushar207',
#     'Comment_PublishedAt': '2022-09-17T13:13:48Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgxdRWgZMHAgr6rtdbF4AaABAg',
#     'Comment_Text': 'Nice',
#     'Comment_Author': '@chinnathambivlogs1769',
#     'Comment_PublishedAt': '2022-07-17T17:41:00Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgydEYEDnKYKELnesgF4AaABAg',
#     'Comment_Text': "Thanks for the video. How to store this checkpoint to blob storage account instead of local file system. I tried replacing the old directory location with my blob storage account https SAS Token but it's not working. Can you please suggest me something ?",
#     'Comment_Author': '@vedantshirodkar',
#     'Comment_PublishedAt': '2022-02-06T08:54:13Z'}}},
#  'Video_Id_12': {'Video_Id': '8zwNJ2vbCck',
#   'Video_Name': '[Live Demo] Python Producer Consumer Problem | Producer & Consumer Multithreading Solution In Python',
#   'Video_Description': 'You will learn how to solve producer consumer problem in python where producer and consumer run in parallel in multithreaded environment and share the same queue. Producer produces the items in the shared queue and consumer consumes the items from shared queue and in case queue is empty then consumer will wait.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/producer-consumer\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['producer',
#    'consumer',
#    'python',
#    'multithreading',
#    'threading',
#    'limeguru'],
#   'PublishedAt': '2021-06-29T16:31:54Z',
#   'View_Count': '3409',
#   'Like_Count': '52',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT6M12S',
#   'Thumbnail': 'https://i.ytimg.com/vi/8zwNJ2vbCck/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgyrXK-UdZsYeDj-v8F4AaABAg',
#     'Comment_Text': "dude wtf 😂😂😂😂, this video is highly misleading. You're using a data structure that is not threadsafe. Plus you're not even showing the race condition. Newbies watching this video will follow the wrong stuff and the whole cycle continues 😐",
#     'Comment_Author': '@gautamjain6122',
#     'Comment_PublishedAt': '2022-02-28T19:21:14Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugyh45rZbKZkBH4zGTF4AaABAg',
#     'Comment_Text': "Mate, You're Supposed to show how to overcome this problem too.......!!",
#     'Comment_Author': '@IDK-tk4mm',
#     'Comment_PublishedAt': '2021-10-25T02:55:29Z'}}},
#  'Video_Id_13': {'Video_Id': 'SVKm-nY0neA',
#   'Video_Name': '[Live Demo] Write Excel Files In Python Using XLWT | XLWT Tutorial | Write XLS Files Using XLWT',
#   'Video_Description': 'You will learn how to write excel files in python using XLWT and how to insert complete dataset in excel sheet.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/write-excel\n\nRead Excel File: \nhttps://youtu.be/bmjI2klio0E\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': '',
#   'PublishedAt': '2021-06-29T11:34:48Z',
#   'View_Count': '1239',
#   'Like_Count': '12',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT3M47S',
#   'Thumbnail': 'https://i.ytimg.com/vi/SVKm-nY0neA/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugz7LKWv6yEGXqoCrC14AaABAg',
#     'Comment_Text': 'how do you delete the particular column of an xls (Excel 97-2003 format) through xlwt ?',
#     'Comment_Author': '@gauravkumarkashyap9353',
#     'Comment_PublishedAt': '2022-03-03T19:38:07Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgwcJJjYp_ioMulPN014AaABAg',
#     'Comment_Text': 'nice',
#     'Comment_Author': '@priyamkakati7674',
#     'Comment_PublishedAt': '2021-07-07T21:13:44Z'}}},
#  'Video_Id_14': {'Video_Id': 'bmjI2klio0E',
#   'Video_Name': '[Live Demo] Read Excel Files In Python Using XLRD | XLRD Tutorial | Read XLS Files Using XLRD',
#   'Video_Description': 'You will learn how to read excel files in python using XLRD with live demo.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/excel\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['xlrd',
#    'read excel',
#    'python',
#    'xls',
#    'xlsx',
#    'file handling',
#    'excel handling',
#    'limeguru',
#    'live demo',
#    'excel example'],
#   'PublishedAt': '2021-06-29T07:16:25Z',
#   'View_Count': '486',
#   'Like_Count': '3',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT4M8S',
#   'Thumbnail': 'https://i.ytimg.com/vi/bmjI2klio0E/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_15': {'Video_Id': 'YGPWzSqvw3A',
#   'Video_Name': '[Live Demo] PyAutoGUI -  Automate Mouse Clicks Using Python | Auto Clicks Using Python',
#   'Video_Description': 'This is pyautogui tutorial where you will learn how to automate mouse clicks using pyautogui python package in your system. The session has live demo of mouse clicks automation happening on browser apps and desktop apps.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/pyautogui\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['pyautogui',
#    'auto clicks',
#    'mouse click',
#    'python',
#    'automation',
#    'browser',
#    'desktop',
#    'system'],
#   'PublishedAt': '2021-06-29T05:59:01Z',
#   'View_Count': '689',
#   'Like_Count': '3',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT6M39S',
#   'Thumbnail': 'https://i.ytimg.com/vi/YGPWzSqvw3A/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_16': {'Video_Id': 'z8jkQIaL7iU',
#   'Video_Name': '[Live Demo] SQLITE3 - Run SQL Queries On Command Line In SQLITE3 | SQLITE3 Tutorial',
#   'Video_Description': 'You will learn sqlite3 sql queries and run directly on sqlite3 file like you do on other relational databases. You will learn how to list tables, create tables, insert data into tables, select data from tables, aggregate functions using sql, group by queries in sqlite3 using sql quaries on sqlite command line terminal.\n\nGITHUB URL:\nhttps://github.com/limegurutech/examples/tree/main/sqlite\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['sqlite3', 'sql', 'queries', 'command line', 'limeguru'],
#   'PublishedAt': '2021-06-28T17:43:34Z',
#   'View_Count': '1881',
#   'Like_Count': '15',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT5M23S',
#   'Thumbnail': 'https://i.ytimg.com/vi/z8jkQIaL7iU/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_17': {'Video_Id': 'X4Jw8egqGzI',
#   'Video_Name': '[Live Demo] Convert Multiple Photos To Video With MoviePy In Python | Python Image Video Processing',
#   'Video_Description': 'You will learn how to combine photos into video using movipy in python.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/photos-to-video\n\nAdd Text To Image Python:\nhttps://youtu.be/g85jQfhG2MU\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['moviepy',
#    'video processing',
#    'image processing',
#    'photos',
#    'videos',
#    'python',
#    'limeguru'],
#   'PublishedAt': '2021-06-28T17:05:32Z',
#   'View_Count': '6505',
#   'Like_Count': '99',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '16',
#   'Duration': 'PT4M37S',
#   'Thumbnail': 'https://i.ytimg.com/vi/X4Jw8egqGzI/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgxmvMNO0RgJ_-6D1Et4AaABAg',
#     'Comment_Text': 'this is best and the easiest  way',
#     'Comment_Author': '@MyindiecraftOfficial',
#     'Comment_PublishedAt': '2023-10-10T07:45:44Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgwvzeX88NPMGmm0Und4AaABAg',
#     'Comment_Text': 'Nice!',
#     'Comment_Author': '@dankogulsoy',
#     'Comment_PublishedAt': '2023-09-01T16:36:34Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgwK_8H091mqv2ced694AaABAg',
#     'Comment_Text': 'I tried the same but output video is not working (only black screen is there)',
#     'Comment_Author': '@dreamcatcher6137',
#     'Comment_PublishedAt': '2022-12-29T18:37:13Z'},
#    'Comment_Id_3': {'Comment_Id': 'Ugwxld0R17t4yDAHOe54AaABAg',
#     'Comment_Text': 'how to add audio?',
#     'Comment_Author': '@gudboi7388',
#     'Comment_PublishedAt': '2022-12-28T11:52:54Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugwmxen2KO5hbp3c5bd4AaABAg',
#     'Comment_Text': 'how to make transition effect between the images??',
#     'Comment_Author': '@abhijitha4132',
#     'Comment_PublishedAt': '2022-01-17T06:36:47Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgxZoMtwuwntqE4uOBR4AaABAg',
#     'Comment_Text': 'من الله توفیق',
#     'Comment_Author': '@goodman2953',
#     'Comment_PublishedAt': '2022-01-05T02:19:15Z'},
#    'Comment_Id_6': {'Comment_Id': 'UgwaGOvhbdUASAoFaJF4AaABAg',
#     'Comment_Text': 'Awesome 👍, can you make a video with scrolling vertically multiple images please, thanks 😊',
#     'Comment_Author': '@dragon3602010',
#     'Comment_PublishedAt': '2022-01-01T06:20:44Z'},
#    'Comment_Id_7': {'Comment_Id': 'UgxDAe8rLweNBSvwjR94AaABAg',
#     'Comment_Text': "I'm getting a blank videi",
#     'Comment_Author': '@naraendrareddy273',
#     'Comment_PublishedAt': '2021-12-12T03:30:39Z'},
#    'Comment_Id_8': {'Comment_Id': 'Ugy6e94FoszDIdzccxV4AaABAg',
#     'Comment_Text': 'how to add audio file as background',
#     'Comment_Author': '@ceuazul9403',
#     'Comment_PublishedAt': '2021-06-29T00:31:15Z'},
#    'Comment_Id_9': {'Comment_Id': 'UgxuW2DdT9fMNmLM7Al4AaABAg',
#     'Comment_Text': 'how to apply a specific format to this video?',
#     'Comment_Author': '@ceuazul9403',
#     'Comment_PublishedAt': '2021-06-28T23:58:21Z'}}},
#  'Video_Id_18': {'Video_Id': 'zr6gJhH5UWo',
#   'Video_Name': '[Live Demo] Mean, Median, Mode In Python | Basic Statistics In Data Science Using Numpy & Scipy',
#   'Video_Description': 'You will learn with code - how to calculate mean, median and mode in python using numpy and pandas package. You will learn to do basic statistics in python for data science projects\n\nGITHUB PROJECT URL:\nhttps://github.com/limegurutech/examples/tree/main/python/mean-median-mode\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['mean', 'median', 'mode', 'python', 'data science', 'statistics'],
#   'PublishedAt': '2021-06-28T15:38:10Z',
#   'View_Count': '171',
#   'Like_Count': '2',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT3M10S',
#   'Thumbnail': 'https://i.ytimg.com/vi/zr6gJhH5UWo/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_19': {'Video_Id': 'Tu4w3wE1HPE',
#   'Video_Name': 'Learn Python Multithreading In 3 Minutes | Python Multithreading Tutorial (Hands-on Tutorials)',
#   'Video_Description': 'You will learn with code python multithreading with python threading example. You will understand how to create threads in python and how to call threads and wait for the threads to finish.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/python-multithreading\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['multithreading', 'threads', 'python', 'limeguru'],
#   'PublishedAt': '2021-06-28T15:07:08Z',
#   'View_Count': '188',
#   'Like_Count': '4',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT3M29S',
#   'Thumbnail': 'https://i.ytimg.com/vi/Tu4w3wE1HPE/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_20': {'Video_Id': 'vpcbHcYGyCY',
#   'Video_Name': 'Learn Python Streamlit In 10 Minutes | Streamlit Tutorial For Beginners (Hands-on Tutorials)',
#   'Video_Description': 'This is streamlit tutorial for beginners and you will learn how to create streamlit python webapp fordata science projects including streamlit installation, sample webapp with data charts and create interactive charts using streamlit.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/streamlit/demo-app\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['streamlit', 'webapp', 'python', 'datascience', 'limeguru'],
#   'PublishedAt': '2021-06-27T10:51:29Z',
#   'View_Count': '335',
#   'Like_Count': '8',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT9M53S',
#   'Thumbnail': 'https://i.ytimg.com/vi/vpcbHcYGyCY/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_21': {'Video_Id': 'ifeW76DfwVg',
#   'Video_Name': 'Learn PyTest In 5 Minutes | What Is PyTest | PyTest Tutorial For Beginners (Hands-on Tutorials)',
#   'Video_Description': 'You will learn pytest framework to write unit test cases in python. pytest is unit testing framework in python. you will write unit test cases with example in python, run unit test cases and generate pytest report in python.\n\n#pytest #python #unittest\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/pytest\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['pytest', 'python', 'unit test case', 'limeguru'],
#   'PublishedAt': '2021-06-27T07:55:12Z',
#   'View_Count': '980',
#   'Like_Count': '14',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT4M38S',
#   'Thumbnail': 'https://i.ytimg.com/vi/ifeW76DfwVg/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_22': {'Video_Id': 'PLH3CPG9r9U',
#   'Video_Name': 'Learn MLFLOW Projects In 8 Minutes | MLFLOW Projects Tutorial For Beginners (Hands-on Tutorials)',
#   'Video_Description': 'You can package data science code using MLFLOW projects and You will learn with code MLFLOW Project with example and how to run mlflow projects and different execution environment supported by mlflow project run like system, conda and docker.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/mlflow/mlflow-pyspark\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['mlflow',
#    'mlflow project',
#    'mlflow projects',
#    'mlflow example',
#    'data science',
#    'machine learning',
#    'pyspark',
#    'word count',
#    'code packaging',
#    'limeguru'],
#   'PublishedAt': '2021-06-27T07:10:35Z',
#   'View_Count': '3392',
#   'Like_Count': '34',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT8M18S',
#   'Thumbnail': 'https://i.ytimg.com/vi/PLH3CPG9r9U/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {}},
#  'Video_Id_23': {'Video_Id': '6afMEjr0mA8',
#   'Video_Name': 'Learn Lambda Expression In Java In 10 Minutes | Lambda Expression Tutorial (Hands-on Tutorials)',
#   'Video_Description': 'You will learn with code how to write lambda expression in java, basics of lambda expression, functional interface in java, writing your custom lambda expression using functional interface and how to pass parameters in lambda expression in java. Lambda expressions were introduced in java version 8 or later. \n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/java/lambda-expression\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['lambda expression',
#    'java',
#    'lambda function',
#    'java tutorial',
#    'lambda expression tutorial',
#    'functional interface',
#    'lambda expression in java'],
#   'PublishedAt': '2021-06-26T11:46:45Z',
#   'View_Count': '93',
#   'Like_Count': '0',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT10M2S',
#   'Thumbnail': 'https://i.ytimg.com/vi/6afMEjr0mA8/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugxiircevrrkh1hCaBh4AaABAg',
#     'Comment_Text': 'Above my head!!!',
#     'Comment_Author': '@fernandohood5542',
#     'Comment_PublishedAt': '2021-07-08T00:44:46Z'}}},
#  'Video_Id_24': {'Video_Id': 'g85jQfhG2MU',
#   'Video_Name': '[Live Demo]  Writing Text On Image Python | Add Text On Photos Programmatically Using Python',
#   'Video_Description': 'You will learn with code to add text to image in python, you will be able to add any text to image using cv2 in python and can do image processing in python. You can also do text wrapping automatically after going through this tutorial session and apply text to images using textwrap in python.\n\nGITHUB CODE URL:\nhttps://github.com/limegurutech/examples/tree/main/python/add-text-to-image\n\n#imageprocessing #python #cv2\n\nLimeguru Website:\r\nhttps://www.limeguru.com\r\n\r\nLimeGuru YouTube Channel\r\nhttps://www.youtube.com/limeguru\r\n\r\nLimeguru Facebook Page\r\nhttps://www.facebook.com/limeguru/',
#   'Tags': ['limeguru',
#    'lime guru',
#    'tech videos',
#    'online learning',
#    'educational videos',
#    'python',
#    'cv2',
#    'image processing',
#    'text wrap'],
#   'PublishedAt': '2021-06-26T06:34:49Z',
#   'View_Count': '2037',
#   'Like_Count': '38',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '5',
#   'Duration': 'PT5M42S',
#   'Thumbnail': 'https://i.ytimg.com/vi/g85jQfhG2MU/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugy0PLBXXsknscNVHWJ4AaABAg',
#     'Comment_Text': 'Nice!',
#     'Comment_Author': '@dankogulsoy',
#     'Comment_PublishedAt': '2023-09-01T17:32:29Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgxI_l0Tbqn8IjSrXYd4AaABAg',
#     'Comment_Text': 'are you able to change the font color ?',
#     'Comment_Author': '@chrisfebo7747',
#     'Comment_PublishedAt': '2022-11-16T21:53:01Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgzDmPZ7KKAgCx2S2514AaABAg',
#     'Comment_Text': "Bro , Thanks for the Tutorial Everything Working Great  but when I try to make Api using flask and import this function then First time Working perfectly but after second time use its like a glitchy text or i ll say its like old text doesn't remove",
#     'Comment_Author': '@HVM-tv9tv',
#     'Comment_PublishedAt': '2021-12-09T15:29:56Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgxOWFiYeyHDv0pyoF54AaABAg',
#     'Comment_Text': 'I want to change font how to do that??',
# ...
#   'Tags': ['spark execution',
#    'spark driver manager',
#    'spark task',
#    'submit spark job',
#    'standalone spark job',
#    'shell based spark job',
#    'spark context',
#    'resilient distributed dataset',
#    'RDD',
#    'spark RDD',
#    'spark code shipping',
#    'spark code execution',
#    'limeguru',
#    'limeguru spark tutorial',
#    'www.limeguru.com'],
#   'PublishedAt': '2017-03-26T12:33:59Z',
#   'View_Count': '29381',
#   'Like_Count': '216',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '13',
#   'Duration': 'PT10M42S',
#   'Thumbnail': 'https://i.ytimg.com/vi/j8tEYOLiv2c/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgylnhVldG4bvyfUQQZ4AaABAg',
#     'Comment_Text': 'very good explanation',
#     'Comment_Author': '@metarealm',
#     'Comment_PublishedAt': '2021-04-02T03:18:19Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgwuF5o0yQgdVdnxS3p4AaABAg',
#     'Comment_Text': 'it has no material whatsoever!',
#     'Comment_Author': '@rajarshidutta8',
#     'Comment_PublishedAt': '2019-05-08T16:51:24Z'},
#    'Comment_Id_2': {'Comment_Id': 'Ugx2jhViqyBb46TJQax4AaABAg',
#     'Comment_Text': 'Before giving a demo, know what ur speaking rather than stopping in between. Or speak in hindi better.',
#     'Comment_Author': '@skc1995',
#     'Comment_PublishedAt': '2019-02-08T18:04:38Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgzscDuBrgDWb55a1Bd4AaABAg',
#     'Comment_Text': 'Spark Runtime Architecture\r\nIn distributed mode, Spark uses a master/slave architecture with one central coordinator and many distributed workers. The central coordinator is called the driver. The driver communicates with a potentially large number of distributed workers called executors. The driver runs in its own Java process and each executor is a separate Java process. A driver and its executors are together termed a Spark application.\r\n\nThe Driver\r\nThe driver is the process where the main() method of your program runs. It is the process running the user code that creates a SparkContext, creates RDDs, and performs\r\ntransformations and actions.\r\n When you launch a Spark shell, you’ve created a driver program (if you remember, the Spark shell comes preloaded with a SparkContext called sc). Once the driver terminates, the application is finished.\r\n When the driver runs, it performs two duties: Converting a user program into tasks The Spark driver is responsible for converting a user program into units of physical execution called tasks. \r\nAt a high level, all Spark programs follow the same structure: they create RDDs from some input, derive new RDDs from those using transformations, and perform actions to collect or save data. \r\nA Spark program implicitly creates a logical directed acyclic graph (DAG) of operations. When the\r\ndriver runs, it converts this logical graph into a physical execution plan.\r\n\r\nSpark performs several optimizations, such as “pipelining” map transformations together to merge them, and converts the execution graph into a set of stages. Each stage, in turn, consists of multiple tasks. The tasks are bundled up and prepared to be sent to the cluster. Tasks are the smallest unit of work in Spark; a typical user program can launch hundreds or thousands of individual tasks. Scheduling tasks on executors Given a physical execution plan, a Spark driver must coordinate the scheduling of individual tasks on executors. When executors are started they register themselves with the driver, so it has a complete view of the application’s executors at all times. \r\nEach executor represents a process capable of running tasks and storing RDD data. The Spark driver will look at the current set of executors and try to schedule each task in an appropriate location, based on data placement. When tasks execute, they may have a side effect of storing cached data. The driver also tracks the location of cached data and uses it to schedule future tasks that access that data. The driver exposes information about the running Spark application through a web interface, which by default is available at port 4040. For instance, in local mode, this UI is available at http://localhost:4040. We’ll cover Spark’s web UI and its scheduling mechanisms in more detail in Chapter 8.\r\n\r\nExecutors\r\nSpark executors are worker processes responsible for running the individual tasks in a given Spark job. Executors are launched once at the beginning of a Spark application and typically run for the entire lifetime of an application, though Spark applications can continue if executors fail. Executors have two roles. First, they run the tasks that make up the application and return results to the driver. Second, they provide in-memory storage for RDDs that are cached by user programs, through a service called the Block Manager  that lives within each executor. Because RDDs are cached directly inside of executors, tasks can run alongside the cached data.\r\n\n\nSummary\r\nTo summarize the concepts in this section, let’s walk through the exact steps that occur when you run a Spark application on a cluster:\r\n1. The user submits an application using spark-submit.\r\n2. spark-submit launches the driver program and invokes the main() method specified by the user.\r\n3. The driver program contacts the cluster manager to ask for resources to launch executors.\r\n4. The cluster manager launches executors on behal ...
#     'Comment_Author': '@rakeshkumarsharma3920',
#     'Comment_PublishedAt': '2019-01-09T16:29:25Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgznbdLZPBb5TcaVyNl4AaABAg',
#     'Comment_Text': 'Very slow audio. I played it with 1.5x speed and found it normal. Please correct it. Contents are fine.',
#     'Comment_Author': '@suren6885',
#     'Comment_PublishedAt': '2018-07-07T05:08:28Z'},
#    'Comment_Id_5': {'Comment_Id': 'UghOArY5-BXV8XgCoAEC',
#     'Comment_Text': 'when you are going to publish the next video regarding RDD.',
#     'Comment_Author': '@siddharthtyagi7524',
#     'Comment_PublishedAt': '2017-04-13T10:03:18Z'},
#    'Comment_Id_6': {'Comment_Id': 'Ugj-vE9m6ptwpXgCoAEC',
#     'Comment_Text': 'Helpful. whats happening behind our code in spark-shell',
#     'Comment_Author': '@dheerajg5253',
#     'Comment_PublishedAt': '2017-04-10T23:22:01Z'}}},
#  'Video_Id_113': {'Video_Id': '89HVV74WwlY',
#   'Video_Name': 'Spark Setup And Installation | Run Your First Spark Program | Step By Step Guide And Code Demo',
#   'Video_Description': 'This session explains step by step guide to download and install Spark on your local. It also covers how you can run your first python program using pyspark shell and scala based program using spark shell.\n\nVisit our website for more tutorials- \nwww.limeguru.com',
#   'Tags': ['spark tutorial',
#    'spark setup',
#    'spark installation',
#    'install spark',
#    'install spark on mac',
#    'install spark on linux',
#    'run first spark program',
#    'run pyspark shell',
#    'spark shell',
#    'run scala program using spark',
#    'spark installation for beginner',
#    'metastore db error in spark shell',
#    'limeguru',
#    'limeguru spark tutorial',
#    'limeguru tutorial'],
#   'PublishedAt': '2017-03-25T19:28:59Z',
#   'View_Count': '6349',
#   'Like_Count': '70',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '1',
#   'Duration': 'PT11M47S',
#   'Thumbnail': 'https://i.ytimg.com/vi/89HVV74WwlY/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'UgwqN-jvp8MMHBYJbYd4AaABAg',
#     'Comment_Text': 'sir where u saved that input.txt file ..',
#     'Comment_Author': '@sheetalirappabetgeri9423',
#     'Comment_PublishedAt': '2018-11-16T10:54:45Z'}}},
#  'Video_Id_114': {'Video_Id': 'xpMi2YSJd00',
#   'Video_Name': 'Java Scheduler Using Spring - Fixed & Cron Scheduling - Working Code Demo',
#   'Video_Description': 'This session explains how you can schedule your java programs to run on certain frequency using spring and maven. There are multiple techniques covered along with code demo.\n\nWe have covered three types of scheduling-\n\n1) Fixed Rate Scheduling\n2) Fixed Delay Scheduling\n3) Cron Scheduling\n\nDownload Source Code:\nhttps://github.com/limegurutech/springjavascheduler',
#   'Tags': ['java scheduler',
#    'java scheduling',
#    'spring scheduling',
#    'spring scheduler',
#    'java scheduler using spring and maven',
#    'fixed rate scheduling using java',
#    'fixed delay scheduling using java',
#    'java cron scheduling',
#    'java cron expression',
#    'cron scheduling',
#    'cron expression',
#    'spring task scheduler',
#    'java task scheduler',
#    'spring annotation scheduler',
#    'cron job',
#    'spring cron job',
#    'java cron job'],
#   'PublishedAt': '2017-03-15T13:44:53Z',
#   'View_Count': '23494',
#   'Like_Count': '167',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '13',
#   'Duration': 'PT12M30S',
#   'Thumbnail': 'https://i.ytimg.com/vi/xpMi2YSJd00/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugx2BU-jaYxm8tJQIrF4AaABAg',
#     'Comment_Text': 'Nice explanation...I will try this tommorow',
#     'Comment_Author': '@rishaworldwithlove',
#     'Comment_PublishedAt': '2019-12-09T17:17:47Z'},
#    'Comment_Id_1': {'Comment_Id': 'UgxPMiHSR6HzS0KhYSJ4AaABAg',
#     'Comment_Text': 'how can we run this with tomcat server, instead of main method ?? please advice',
#     'Comment_Author': '@fahimnaeem6833',
#     'Comment_PublishedAt': '2019-12-09T00:53:14Z'},
#    'Comment_Id_2': {'Comment_Id': 'UgyNs9c1EBSQfei_4-t4AaABAg',
#     'Comment_Text': 'very nice explanation but if you explain stars in corn is excellent',
#     'Comment_Author': '@balakrishna2571',
#     'Comment_PublishedAt': '2019-09-24T12:36:05Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgwSkrMs1dEoFcqS3A14AaABAg',
#     'Comment_Text': 'How do i update database using same concept with JDBCTemplate in Spring 4',
#     'Comment_Author': '@thedifferent7562',
#     'Comment_PublishedAt': '2018-10-12T08:23:02Z'},
#    'Comment_Id_4': {'Comment_Id': 'UgybrF9Uj_zN4cQ9aT54AaABAg',
#     'Comment_Text': 'I prefer Spring-Task-Scheduling over Quartz-Scheduler.',
#     'Comment_Author': '@umeshjavamentor9239',
#     'Comment_PublishedAt': '2018-02-26T10:13:52Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgxHpTWscWZRWjzCKPl4AaABAg',
#     'Comment_Text': "It's working. Thank you.",
#     'Comment_Author': '@gayanrupasinghe8356',
#     'Comment_PublishedAt': '2018-02-06T07:26:28Z'},
#    'Comment_Id_6': {'Comment_Id': 'Ugim92P-vOHZG3gCoAEC',
#     'Comment_Text': 'please share the link to download the code.',
#     'Comment_Author': '@priyamk1821',
#     'Comment_PublishedAt': '2017-07-13T07:07:54Z'},
#    'Comment_Id_7': {'Comment_Id': 'Ugi48TAGfzQcvHgCoAEC',
#     'Comment_Text': 'sup of super fucking good',
#     'Comment_Author': '@tuanduong3974',
#     'Comment_PublishedAt': '2017-07-04T10:38:01Z'},
#    'Comment_Id_8': {'Comment_Id': 'UgiYJJGfoghThngCoAEC',
#     'Comment_Text': 'extra hyper good',
#     'Comment_Author': '@tuanduong3974',
#     'Comment_PublishedAt': '2017-07-04T10:37:44Z'},
#    'Comment_Id_9': {'Comment_Id': 'UgjEdPvR94DhCXgCoAEC',
#     'Comment_Text': 'hyper good',
#     'Comment_Author': '@tuanduong3974',
#     'Comment_PublishedAt': '2017-07-04T10:37:32Z'},
#    'Comment_Id_10': {'Comment_Id': 'UgiSiC79JmIB5XgCoAEC',
#     'Comment_Text': 'very good',
#     'Comment_Author': '@tuanduong3974',
#     'Comment_PublishedAt': '2017-07-04T10:37:24Z'},
#    'Comment_Id_11': {'Comment_Id': 'Ugjlnc-BMEOe9XgCoAEC',
#     'Comment_Text': 'good',
#     'Comment_Author': '@tuanduong3974',
#     'Comment_PublishedAt': '2017-07-04T10:37:00Z'},
#    'Comment_Id_12': {'Comment_Id': 'UgiFcwy260rpjXgCoAEC',
#     'Comment_Text': 'good',
#     'Comment_Author': '@tuanduong3974',
#     'Comment_PublishedAt': '2017-07-04T10:36:54Z'}}},
#  'Video_Id_115': {'Video_Id': 'wWVaVxr4GTE',
#   'Video_Name': 'What is Spark? - Spark Tutorials For Beginners',
#   'Video_Description': 'This is a introductory Spark session for beginners who want to learn data analysis using spark along with its features, benefits, and trends.\n \nIn this session, we will cover following Spark topics-\n\n1. What is Spark?\n2. How Spark is faster for data analysis?\n3. Features of Spark\n4. Who should use Spark?\n5. Spark cluster managers',
#   'Tags': ['Spark tutorials',
#    'spark tutorials for beginners',
#    'what is spark',
#    'spark is faster',
#    'spark vs map reduce',
#    'spark for data scientist',
#    'spark cluster manager',
#    'spark standalone schedular',
#    'apache spark'],
#   'PublishedAt': '2017-01-13T19:40:28Z',
#   'View_Count': '15136',
#   'Like_Count': '204',
#   'Dislike_Count': 0,
#   'Favorite_Count': '0',
#   'Comment_Count': '13',
#   'Duration': 'PT22M4S',
#   'Thumbnail': 'https://i.ytimg.com/vi/wWVaVxr4GTE/sddefault.jpg',
#   'Caption_Status': 'false',
#   'Comments': {'Comment_Id_0': {'Comment_Id': 'Ugw2VzsXo5AKco9NOTp4AaABAg',
#     'Comment_Text': 'map reduce can also be in standalone',
#     'Comment_Author': '@karth12399',
#     'Comment_PublishedAt': '2023-06-07T17:55:26Z'},
#    'Comment_Id_1': {'Comment_Id': 'Ugz6inwuG9B2sdpL-vh4AaABAg',
#     'Comment_Text': 'Nice explanation',
#     'Comment_Author': '@adwaitkesharwani3569',
#     'Comment_PublishedAt': '2022-02-10T16:42:44Z'},
#    'Comment_Id_2': {'Comment_Id': 'Ugx3q0WkmcztDbpfiCR4AaABAg',
#     'Comment_Text': 'Nice explanation and in crispy way',
#     'Comment_Author': '@pravee150',
#     'Comment_PublishedAt': '2021-09-27T19:17:08Z'},
#    'Comment_Id_3': {'Comment_Id': 'UgyA88OmkvjNe0zZiwl4AaABAg',
#     'Comment_Text': 'What is this weird background noise? Content is good btw',
#     'Comment_Author': '@rujhanarora7892',
#     'Comment_PublishedAt': '2021-08-01T20:00:03Z'},
#    'Comment_Id_4': {'Comment_Id': 'Ugwyz7yGK8DafamCEQ54AaABAg',
#     'Comment_Text': "It's really awesome",
#     'Comment_Author': '@bhavaniv1721',
#     'Comment_PublishedAt': '2020-12-13T10:30:24Z'},
#    'Comment_Id_5': {'Comment_Id': 'UgzWU4Lnuk_8ifPzTWZ4AaABAg',
#     'Comment_Text': 'thanks bro . I am a java WEB developer with HADOOP handson. I always wanted to learn spark',
#     'Comment_Author': '@subramanianchenniappan4059',
#     'Comment_PublishedAt': '2020-05-25T16:30:54Z'},
#    'Comment_Id_6': {'Comment_Id': 'Ugx1bDogfNUSwULN6RF4AaABAg',
#     'Comment_Text': 'Awesome ❤️',
#     'Comment_Author': '@khalidjaradat',
#     'Comment_PublishedAt': '2019-11-16T06:52:07Z'},
#    'Comment_Id_7': {'Comment_Id': 'UgwK6KoiLJ4urDqs7Bd4AaABAg',
#     'Comment_Text': 'Thank you for such nice video tutorials on Spark.',
#     'Comment_Author': '@GoutamSikder',
#     'Comment_PublishedAt': '2019-06-06T05:32:50Z'},
#    'Comment_Id_8': {'Comment_Id': 'Ugz_Pj6ADtNUgXB-MDx4AaABAg',
#     'Comment_Text': 'Hi Can,you please make paid videos.I really found your tuotrials  helpful..',
#     'Comment_Author': '@NaturalPro100',
#     'Comment_PublishedAt': '2018-12-24T08:28:54Z'},
#    'Comment_Id_9': {'Comment_Id': 'Ugz6JYL--maBxyHlAjh4AaABAg',
#     'Comment_Text': 'Very clearly explained \nGreat job',
#     'Comment_Author': '@smritidey2942',
#     'Comment_PublishedAt': '2017-10-08T13:07:31Z'},
#    'Comment_Id_10': {'Comment_Id': 'UgheKXB0l12ZJXgCoAEC',
#     'Comment_Text': 'provides good theoretical understanding of spark features and concepts.',
#     'Comment_Author': '@priyankachawla6854',
#     'Comment_PublishedAt': '2017-06-15T06:23:56Z'},
#    'Comment_Id_11': {'Comment_Id': 'UgjbGTQPlPHV9XgCoAEC',
#     'Comment_Text': 'very theoretical',
#     'Comment_Author': '@kaushikdujo',
#     'Comment_PublishedAt': '2017-05-20T02:47:06Z'}}}}

# %% [markdown]
# ### Adding Data to MongoDB

# %%
import pymongo as py

# %%
connect = py.MongoClient("mongodb+srv://Logan:Logan1116@mongo1.7lgrplr.mongodb.net/?retryWrites=true&w=majority")

# %%
#Creates Database
db = connect['Capstudy']

#Creating collection
col = db['Youtube']

#Inserting 1st Channel Details
col.insert_one(x)
# Out:
# InsertOneResult(ObjectId('656e218892db13bdf36ffc20'), acknowledged=True)

# %%
import pandas as pd

# %%
#Fetching the data from Mongodb
dbb = connect.Capstudy
collection = dbb.Youtube
data = pd.DataFrame(list(collection.find()))

# %%
data
# Out:
#                         _id  \
# 0  656e218892db13bdf36ffc20
#
#                                         Channel_Name  \
# 0  {'channel_name': 'Cognitive Hub', 'channel_id'...
#
#                                           Video_Id_1  \
# 0  {'Video_Id': 'Y_mWy11SxTo', 'Video_Name': '8. ...
#
#                                           Video_Id_2  \
# 0  {'Video_Id': 'G6vIcZ-A1QA', 'Video_Name': '7. ...
#
#                                           Video_Id_3  \
# 0  {'Video_Id': 'iE0J837gSIc', 'Video_Name': '6. ...
#
#                                           Video_Id_4  \
# 0  {'Video_Id': 'HaLkoXi8kaA', 'Video_Name': '5. ...
#
#                                           Video_Id_5  \
# 0  {'Video_Id': 'Y3FJceP6MR4', 'Video_Name': '4. ...
#
#                                           Video_Id_6  \
# 0  {'Video_Id': 'dH99q1vBqNQ', 'Video_Name': '3. ...
#
#                                           Video_Id_7  \
# 0  {'Video_Id': '2FNnLwaacQc', 'Video_Name': '2. ...
#
#                                           Video_Id_8  ...  \
# 0  {'Video_Id': 'Bqypojx4knM', 'Video_Name': '1. ...  ...
#
#                                         Video_Id_183  \
# 0  {'Video_Id': 'LdaTV29nLrw', 'Video_Name': 'VBA...
#
#                                         Video_Id_184  \
# 0  {'Video_Id': '9cjWmqq7iq4', 'Video_Name': 'VBA...
#
#                                         Video_Id_185  \
# 0  {'Video_Id': 'uQbAqAdJ_t0', 'Video_Name': 'VBA...
#
#                                         Video_Id_186  \
# 0  {'Video_Id': '60tD4sC2uzs', 'Video_Name': 'VBA...
#
#                                         Video_Id_187  \
# 0  {'Video_Id': '0l84yFa477k', 'Video_Name': 'VBA...
#
#                                         Video_Id_188  \
# 0  {'Video_Id': 'BofFLwQh-Pw', 'Video_Name': 'VBA...
#
#                                         Video_Id_189  \
# 0  {'Video_Id': 'DPLkSL72l1A', 'Video_Name': 'VBA...
#
#                                         Video_Id_190  \
# 0  {'Video_Id': 'PvoZN9DchD4', 'Video_Name': 'VBA...
#
#                                         Video_Id_191  \
# 0  {'Video_Id': '4oCoq8upoSo', 'Video_Name': 'VBA...
#
#                                         Video_Id_192
# 0  {'Video_Id': 'yMj0AvWD_CY', 'Video_Name': 'Ena...
#
# [1 rows x 194 columns]

# %%
#Adding another Channle Detial
col.insert_one(y)
# Out:
# InsertOneResult(ObjectId('656e21d692db13bdf36ffc21'), acknowledged=True)

# %%
#Fetching the data from Mongodb
dbb = connect.Capstudy
collection = dbb.Youtube
data = pd.DataFrame(list(collection.find()))

# %%
data
# Out:
#                         _id  \
# 0  656e218892db13bdf36ffc20
# 1  656e21d692db13bdf36ffc21
#
#                                         Channel_Name  \
# 0  {'channel_name': 'Cognitive Hub', 'channel_id'...
# 1  {'channel_name': 'LimeGuru', 'channel_id': 'UC...
#
#                                           Video_Id_1  \
# 0  {'Video_Id': 'Y_mWy11SxTo', 'Video_Name': '8. ...
# 1  {'Video_Id': 'G9RY23vmV00', 'Video_Name': 'Doc...
#
#                                           Video_Id_2  \
# 0  {'Video_Id': 'G6vIcZ-A1QA', 'Video_Name': '7. ...
# 1  {'Video_Id': 'ulGsYjxuMHk', 'Video_Name': 'Doc...
#
#                                           Video_Id_3  \
# 0  {'Video_Id': 'iE0J837gSIc', 'Video_Name': '6. ...
# 1  {'Video_Id': 'O5e_o1H3uVc', 'Video_Name': 'Lea...
#
#                                           Video_Id_4  \
# 0  {'Video_Id': 'HaLkoXi8kaA', 'Video_Name': '5. ...
# 1  {'Video_Id': '3mrdQSRDmk4', 'Video_Name': 'Lea...
#
#                                           Video_Id_5  \
# 0  {'Video_Id': 'Y3FJceP6MR4', 'Video_Name': '4. ...
# 1  {'Video_Id': 'aiesECaegyQ', 'Video_Name': 'Lea...
#
#                                           Video_Id_6  \
# 0  {'Video_Id': 'dH99q1vBqNQ', 'Video_Name': '3. ...
# 1  {'Video_Id': 'QfsXKdm0uys', 'Video_Name': 'Lea...
#
#                                           Video_Id_7  \
# 0  {'Video_Id': '2FNnLwaacQc', 'Video_Name': '2. ...
# 1  {'Video_Id': 'NDehMPl6Vfs', 'Video_Name': 'Lea...
#
#                                           Video_Id_8  ...  \
# 0  {'Video_Id': 'Bqypojx4knM', 'Video_Name': '1. ...  ...
# 1  {'Video_Id': 'IKa7Kx5IQIA', 'Video_Name': '[Li...  ...
#
#                                         Video_Id_183  \
# 0  {'Video_Id': 'LdaTV29nLrw', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_184  \
# 0  {'Video_Id': '9cjWmqq7iq4', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_185  \
# 0  {'Video_Id': 'uQbAqAdJ_t0', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_186  \
# 0  {'Video_Id': '60tD4sC2uzs', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_187  \
# 0  {'Video_Id': '0l84yFa477k', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_188  \
# 0  {'Video_Id': 'BofFLwQh-Pw', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_189  \
# 0  {'Video_Id': 'DPLkSL72l1A', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_190  \
# 0  {'Video_Id': 'PvoZN9DchD4', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_191  \
# 0  {'Video_Id': '4oCoq8upoSo', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_192
# 0  {'Video_Id': 'yMj0AvWD_CY', 'Video_Name': 'Ena...
# 1                                                NaN
#
# [2 rows x 194 columns]

# %% [markdown]
# ### Adding Data to SQL based on given Channel ID

# %%
import sqlalchemy as sq
from pandas.io import sql
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd

# %%
#Connecting to MY SQL Local Instance

user='root'
pwd='3008'
host = 'localhost'
port = '3306'
db= 'YT'
engine = create_engine(f"mysql+pymysql://{user}:{pwd}@{host}:{port}/{db}")
#df.to_sql(con=engine, name='chanel', if_exists='replace')

# %%
#Checking all the tables and there values

query = 'select * from Channels;'
op = pd.read_sql_query(sql=text(query),con=engine.connect())
op
# Out:
# Empty DataFrame
# Columns: [channel_id, channel_name, channel_type, channel_views, channel_description, channel_status]
# Index: []

# %%
query = 'select * from Videos;'
op = pd.read_sql_query(sql=text(query),con=engine.connect())
op
# Out:
# Empty DataFrame
# Columns: [video_id, channel_id, video_name, video_desc, published_date, view_count, like_count, dislike_count, favorite_count, comment_count, duration, thumbnail, caption_status]
# Index: []

# %%
query = 'select * from Comments;'
op = pd.read_sql_query(sql=text(query),con=engine.connect())
op
# Out:
# Empty DataFrame
# Columns: [comment_id, video_id, comment_text, comment_author, comment_published_date]
# Index: []

# %%
#This is the Dataframe which has all fetched data from MongoDB
data
# Out:
#                         _id  \
# 0  656e218892db13bdf36ffc20
# 1  656e21d692db13bdf36ffc21
#
#                                         Channel_Name  \
# 0  {'channel_name': 'Cognitive Hub', 'channel_id'...
# 1  {'channel_name': 'LimeGuru', 'channel_id': 'UC...
#
#                                           Video_Id_1  \
# 0  {'Video_Id': 'Y_mWy11SxTo', 'Video_Name': '8. ...
# 1  {'Video_Id': 'G9RY23vmV00', 'Video_Name': 'Doc...
#
#                                           Video_Id_2  \
# 0  {'Video_Id': 'G6vIcZ-A1QA', 'Video_Name': '7. ...
# 1  {'Video_Id': 'ulGsYjxuMHk', 'Video_Name': 'Doc...
#
#                                           Video_Id_3  \
# 0  {'Video_Id': 'iE0J837gSIc', 'Video_Name': '6. ...
# 1  {'Video_Id': 'O5e_o1H3uVc', 'Video_Name': 'Lea...
#
#                                           Video_Id_4  \
# 0  {'Video_Id': 'HaLkoXi8kaA', 'Video_Name': '5. ...
# 1  {'Video_Id': '3mrdQSRDmk4', 'Video_Name': 'Lea...
#
#                                           Video_Id_5  \
# 0  {'Video_Id': 'Y3FJceP6MR4', 'Video_Name': '4. ...
# 1  {'Video_Id': 'aiesECaegyQ', 'Video_Name': 'Lea...
#
#                                           Video_Id_6  \
# 0  {'Video_Id': 'dH99q1vBqNQ', 'Video_Name': '3. ...
# 1  {'Video_Id': 'QfsXKdm0uys', 'Video_Name': 'Lea...
#
#                                           Video_Id_7  \
# 0  {'Video_Id': '2FNnLwaacQc', 'Video_Name': '2. ...
# 1  {'Video_Id': 'NDehMPl6Vfs', 'Video_Name': 'Lea...
#
#                                           Video_Id_8  ...  \
# 0  {'Video_Id': 'Bqypojx4knM', 'Video_Name': '1. ...  ...
# 1  {'Video_Id': 'IKa7Kx5IQIA', 'Video_Name': '[Li...  ...
#
#                                         Video_Id_183  \
# 0  {'Video_Id': 'LdaTV29nLrw', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_184  \
# 0  {'Video_Id': '9cjWmqq7iq4', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_185  \
# 0  {'Video_Id': 'uQbAqAdJ_t0', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_186  \
# 0  {'Video_Id': '60tD4sC2uzs', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_187  \
# 0  {'Video_Id': '0l84yFa477k', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_188  \
# 0  {'Video_Id': 'BofFLwQh-Pw', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_189  \
# 0  {'Video_Id': 'DPLkSL72l1A', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_190  \
# 0  {'Video_Id': 'PvoZN9DchD4', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_191  \
# 0  {'Video_Id': '4oCoq8upoSo', 'Video_Name': 'VBA...
# 1                                                NaN
#
#                                         Video_Id_192
# 0  {'Video_Id': 'yMj0AvWD_CY', 'Video_Name': 'Ena...
# 1                                                NaN
#
# [2 rows x 194 columns]

# %%
# !pip install isodate
# Out:
# Requirement already satisfied: isodate in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (0.6.1)
# Requirement already satisfied: six in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from isodate) (1.16.0)

# %%
import isodate
from datetime import datetime, timezone
import datetime

# %%
def dateTrans(x):
    return isodate.parse_duration(x).total_seconds()

# %%
def convertDate(d):
     curr_date = d.replace("T", ' ')
     new_date = curr_date.replace('Z','')
     return new_date

# %%
def getDetails(cId,data):
    x = data.shape[0]
    rw_c = data.shape[1]
    for i in range(x):
        if data.iat[i,1]['channel_id'] == cId:
            chl_MDB = data['Channel_Name'][i]
            chl_df = pd.DataFrame.from_dict(chl_MDB,orient = 'index')
            chl_df = chl_df.transpose()
            chl_df = chl_df.drop(['playlists','subscription_count'],axis = 1)
            chl_df = chl_df.assign(channel_status='Active')
            chl_df = chl_df.assign(channel_type='Education')
            chl_df = chl_df[['channel_id','channel_name','channel_type','channel_views','channel_description','channel_status']]

            vee_df = pd.DataFrame(columns = ['Video_Id', 'Video_Name', 'Video_Description','Tags','PublishedAt',
                                             'View_Count','Like_Count','Dislike_Count','Favorite_Count','Comment_Count',
                                             'Duration','Thumbnail','Caption_Status','Comments'])
            cd = data['Channel_Name'][i]['channel_id']
            for j in range(2,rw_c):
                ved_df = data.iat[i,j]
                v_df = pd.DataFrame.from_dict(ved_df,orient = 'index')
                v_df = v_df.transpose()
                vee_df = pd.concat([vee_df,v_df])
                xy = data.iat[i,j]['Duration']
                xyz = isodate.parse_duration(xy).total_seconds()
                vee_df['Duration'].replace(xy, xyz, inplace = True)
                vee_df['PublishedAt'] = vee_df['PublishedAt'].apply(convertDate)
                vee_df = vee_df.drop(['Tags','Comments'],axis = 1)
                vee_df = vee_df.assign(Channel_Id=cd)
                vee_df = vee_df [['Video_Id','Channel_Id', 'Video_Name', 'Video_Description', 
                                  'PublishedAt','View_Count', 'Like_Count', 'Dislike_Count', 
                                  'Favorite_Count','Comment_Count', 'Duration', 'Thumbnail', 'Caption_Status']]

            
            cmtt_df = pd.DataFrame(columns = ['Comment_Id', 'Comment_Text', 'Comment_Author','Comment_PublishedAt','Video_Id'])
            s = 0
            for k in range(2,rw_c):
                ct_df = data.iat[0,k]['Comments']
                s = len(data.iat[0,k]['Comments'].keys())
                if s ==0:
                    continue
                else:
                    for l in range(s):
                        t = 'Comment_Id_'
                        t = t + str(l)
                        ctt_df = ct_df[t] 
                        c_df = pd.DataFrame.from_dict(ctt_df,orient = 'index')
                        c_df = c_df.transpose()
                        c_df['Video_Id'] = data.iat[0,k]['Video_Id']
                        cmtt_df = pd.concat([cmtt_df,c_df])
                        cmtt_df['Comment_PublishedAt'] = cmtt_df['Comment_PublishedAt'].apply(convertDate)
            #cmtt_df = [['Comment_Id', 'Video_Id', 'Comment_Text', 'Comment_Author','Comment_PublishedAt']]
                        
    return chl_df,vee_df,cmtt_df

# %%
#Selecting the which channel detaials need to be added in MYSQL

inp = input("Enter Channel ID")

c1 = data.shape[0]

for i in range(c1):
    if data.iat[i,1]['channel_id'] == inp:
        channel,video,comments = getDetails(inp,data)
    else:
        print("Enter Proper Channel")
comments



#UCu3BMqFAS8gKBXwNHdKM88w
# Out:
# Enter Channel ID UCu3BMqFAS8gKBXwNHdKM88w
# Enter Proper Channel
#                     Comment_Id  \
# 0   UgyrgVLaVq7YZ8rugCh4AaABAg
# 0   Ugxo_ggvKb1OCqzU2_l4AaABAg
# 0   UgwrWvurbQ6FgZJDNA94AaABAg
# 0   UgytncheWXSzXABY1eZ4AaABAg
# 0   UgySa5WMLUwamwIBdzp4AaABAg
# ..                         ...
# 0   Ugy-qCyt7s_dXD_LvmB4AaABAg
# 0   UgwjRsOFqFwKoeI8MX54AaABAg
# 0   UgydaDcmNwrMJQxS6dJ4AaABAg
# 0   UgzYDZeKhbmqNmxZR3B4AaABAg
# 0   UgwquvHiOJU46VqjP8J4AaABAg
#
#                                          Comment_Text        Comment_Author  \
# 0   Hi bro nenu abinitio etl tool meda work chestu...          @naveeng1752
# 0   Hi bro how can i convert string variables into...          @Ayush-jk2tu
# 0                           I want to connect you sir    @relaxingmusic5932
# 0          Hi sir I need to learn talend pls help mee    @relaxingmusic5932
# 0   hii anna naku oka doubt vundee talend open stu...    @relaxingmusic5932
# ..                                                ...                   ...
# 0   I am getting the following error when I try to...  @atharvayeolekar5837
# 0   Good video bro, keep it up. 1 question , if th...        @RaMaUnplugged
# 0   while running a job I am getting the error "th...          @Vikranth4A5
# 0                                     Super bro 😍😍😍😍😍          @TheKiddyBoy
# 0                                     Great work bro😊       @ammuluinti5372
#
#     Comment_PublishedAt     Video_Id
# 0   2023-09-24 17:32:36  Y_mWy11SxTo
# 0   2023-08-15 13:42:39  Y_mWy11SxTo
# 0   2023-07-17 06:26:27  Y_mWy11SxTo
# 0   2023-07-17 06:25:52  Y_mWy11SxTo
# 0   2023-06-15 17:44:02  Y_mWy11SxTo
# ..                  ...          ...
# 0   2021-02-15 04:10:40  0qEEOeszI7g
# 0   2021-02-04 17:43:44  0qEEOeszI7g
# 0   2021-01-20 08:42:56  0qEEOeszI7g
# 0   2020-05-17 13:57:13  0qEEOeszI7g
# 0   2020-04-23 05:30:59  EQ--0G8DGcM
#
# [930 rows x 5 columns]

# %%
video
# Out:
#        Video_Id                Channel_Id  \
# 0   Y_mWy11SxTo  UCu3BMqFAS8gKBXwNHdKM88w
# 0   G6vIcZ-A1QA  UCu3BMqFAS8gKBXwNHdKM88w
# 0   iE0J837gSIc  UCu3BMqFAS8gKBXwNHdKM88w
# 0   HaLkoXi8kaA  UCu3BMqFAS8gKBXwNHdKM88w
# 0   Y3FJceP6MR4  UCu3BMqFAS8gKBXwNHdKM88w
# ..          ...                       ...
# 0   BofFLwQh-Pw  UCu3BMqFAS8gKBXwNHdKM88w
# 0   DPLkSL72l1A  UCu3BMqFAS8gKBXwNHdKM88w
# 0   PvoZN9DchD4  UCu3BMqFAS8gKBXwNHdKM88w
# 0   4oCoq8upoSo  UCu3BMqFAS8gKBXwNHdKM88w
# 0   yMj0AvWD_CY  UCu3BMqFAS8gKBXwNHdKM88w
#
#                                            Video_Name  \
# 0   8. How to archive files in AWS S3 using Talend...
# 0   7. How to copy files from one bucket to anothe...
# 0   6. How to retrieve contents from a S3 Bucket u...
# 0   5. How to send files from talend studio to AWS...
# 0   4. How to retrieve files from AWS S3 Buckets t...
# ..                                                ...
# 0   VBA If Else and Select Statements l VBA l Exce...
# 0   VBA Operators and Operands l VBA l Excel Progr...
# 0   VBA Variables and Data Types I VBA I Excel Pro...
# 0   VBA Comments, Constants, MsgBox and InputBox I...
# 0   Enabling Developer Option in Excel l VBA l Exc...
#
#                                     Video_Description          PublishedAt  \
# 0   #####Talend AWS Tutorials####\n\n#S3Components...  2023-06-14 04:00:28
# 0   #####Talend AWS Tutorials####\n\n#S3Components...  2023-06-07 04:00:07
# 0   #####Talend AWS Tutorials####\n\n#S3Components...  2023-05-31 04:00:16
# 0   #####Talend AWS Tutorials####\n\n#S3Components...  2023-05-24 04:00:15
# 0   #####Talend AWS Tutorials####\n\n#S3Components...  2023-05-17 04:00:25
# ..                                                ...                  ...
# 0   #VBAIfElse #VBASelect\n#####Excel VBA Programm...  2020-04-22 16:01:53
# 0   #VBAOperators #VBAOperands #Excel\n\n\n#####Ex...  2020-04-22 15:54:33
# 0   #VBA #Variables #VBADatatypes\n#####Excel VBA ...  2020-04-22 15:19:33
# 0   #Excel #VBA #ExcelMacros\n##### Excel VBA Prog...  2020-04-22 15:01:05
# 0   #####Excel VBA Programming for Beginners####\n...  2020-04-22 14:34:43
#
#    View_Count Like_Count Dislike_Count Favorite_Count Comment_Count  Duration  \
# 0         332          3             0              0             6     686.0
# 0         289          3             0              0             0     389.0
# 0         532          7             0              0             2     436.0
# 0         494          8             0              0             1     298.0
# 0         730          8             0              0             1     446.0
# ..        ...        ...           ...            ...           ...       ...
# 0          34          2             0              0             0     946.0
# 0         155          4             0              0             0     693.0
# 0          93          5             0              0             0     643.0
# 0          83          4             0              0             0     754.0
# 0         243          9             0              0             0     439.0
#
#                                            Thumbnail Caption_Status
# 0   https://i.ytimg.com/vi/Y_mWy11SxTo/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/G6vIcZ-A1QA/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/iE0J837gSIc/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/HaLkoXi8kaA/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/Y3FJceP6MR4/sddefault.jpg          false
# ..                                               ...            ...
# 0   https://i.ytimg.com/vi/BofFLwQh-Pw/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/DPLkSL72l1A/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/PvoZN9DchD4/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/4oCoq8upoSo/sddefault.jpg          false
# 0   https://i.ytimg.com/vi/yMj0AvWD_CY/sddefault.jpg          false
#
# [192 rows x 13 columns]

# %%
channel.to_sql('Channels', con=engine, if_exists='append',index = False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry 'UCu3BMqFAS8gKBXwNHdKM88w' for key 'channels.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 channel.to_sql('Channels', con=engine, if_exists='append',index = False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)
#    1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:1507, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1505 if re.search(msg, err_text):
#    1506     raise ValueError("inf cannot be used with MySQL") from err
# -> 1507 raise err
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)
#     948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\sql\elements.py:516, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     514     if TYPE_CHECKING:
#     515         assert isinstance(self, Executable)
# --> 516     return connection._execute_clauseelement(
#     517         self, distilled_params, execution_options
#     518     )
#     519 else:
#     520     raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'UCu3BMqFAS8gKBXwNHdKM88w' for key 'channels.PRIMARY'")
# [SQL: INSERT INTO `Channels` (channel_id, channel_name, channel_type, channel_views, channel_description, channel_status) VALUES (%(channel_id)s, %(channel_name)s, %(channel_type)s, %(channel_views)s, %(channel_description)s, %(channel_status)s)]
# [parameters: {'channel_id': 'UCu3BMqFAS8gKBXwNHdKM88w', 'channel_name': 'Cognitive Hub', 'channel_type': 'Education', 'channel_views': '781339', 'channel_description': 'Work Hard until Light of your Study Table becomes Spot Light of Stage.\n\nLinkedIn URL:  https://www.linkedin.com/in/venkata-subba-rao-inti-21574617a/ \n\nMail : ivsr517@gmail.com\n\nBlogSpot: https://cognitivehub2020.blogspot.com/\n', 'channel_status': 'Active'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
video.columns
# Out:
# Index(['Video_Id', 'Channel_Id', 'Video_Name', 'Video_Description',
#        'PublishedAt', 'View_Count', 'Like_Count', 'Dislike_Count',
#        'Favorite_Count', 'Comment_Count', 'Duration', 'Thumbnail',
#        'Caption_Status'],
#       dtype='object')

# %%
video.to_sql('Videos', con=engine, if_exists='append',index = False)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_25264\2899550565.py:1: UserWarning: The provided table name 'Videos' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   video.to_sql('Videos', con=engine, if_exists='append',index = False)
# 192

# %%
comments.columns
# Out:
# Index(['Comment_Id', 'Comment_Text', 'Comment_Author', 'Comment_PublishedAt',
#        'Video_Id'],
#       dtype='object')

# %%
comments.to_sql('Comments', con=engine, if_exists='append',index = False)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_25264\1072241799.py:1: UserWarning: The provided table name 'Comments' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   comments.to_sql('Comments', con=engine, if_exists='append',index = False)
# 930

# %%
vee_df['PublishedAt'].apply(convertDate)
